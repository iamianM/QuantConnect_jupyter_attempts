# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-LLC/FinRL-Library/blob/master/FinRL_ensemble_stock_trading_ICAIF_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from torchvision.models.resnet import resnet18

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading Using Ensemble Strategy
#
# Tutorials to use OpenAI DRL to trade multiple stocks using ensemble strategy in one Jupyter Notebook | Presented at ICAIF 2020
#
# * This notebook is the reimplementation of our paper: Deep Reinforcement Learning for Automated Stock Trading: An Ensemble Strategy, using FinRL.
# * Check out medium blog for detailed explanations: https://medium.com/@ai4finance/deep-reinforcement-learning-for-automated-stock-trading-f1dad0126a02
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
# ## install finrl library
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.interactive(False)
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import datetime

from finrl.config import config
from finrl.marketdata.yahoodownloader import YahooDownloader
from finrl.preprocessing.preprocessors import FeatureEngineer
from finrl.preprocessing.data import data_split
from finrl.env.env_stocktrading import StockTradingEnv
from stable_baselines3.common.vec_env import SubprocVecEnv
from finrl.model.models import DRLAgent, DRLEnsembleAgent
from finrl.trade.backtest import backtest_stats, backtest_plot, get_daily_return, get_baseline
from stable_baselines3 import A2C

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
import zipfile
import datetime

# %%
import torch

torch.cuda.is_available(),torch.cuda.current_device(),torch.cuda.device(0),torch.cuda.device_count(),torch.cuda.get_device_name(0)
# Out:
# (True, 0, <torch.cuda.device at 0x1b008f1e848>, 1, 'GeForce GTX 1070 Ti')

# %%
matplotlib.get_backend()
# Out:
# 'agg'

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# df = pd.read_csv("C:/Users/Mcian/Downloads/day_trader_bot/dukascopy/TSLA.USUSD_Candlestick_1_M_BID_30.03.2018-30.03.2021.csv")
# df = df[df['Volume'] > 0]
# df = pd.concat([df, 
#                 pd.read_csv("C:/Users/Mcian/Downloads/day_trader_bot/dukascopy/BTCUSD_Candlestick_1_M_BID_17.03.2018-17.03.2021.csv")])
zf = zipfile.ZipFile('firstratedata/us3000_tickers_S-T_1min_76pab.zip') 
df = pd.read_csv(zf.open('TSLA_1min.txt'), names=['Local time', 'Open', 'High', 'Low', 'Close', 'Volume'])


df['tic'] = 'TSLA'
df = df.iloc[1225000:]
df['Local time'] = pd.to_datetime(df['Local time'])
df = df.resample('min', on='Local time').max().fillna(method='ffill')
df = df[[t.time() > datetime.time(9, 30) and t.time() < datetime.time(16, 30) for t in df['Local time']]]
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-12-3dd348c1cff3> in <module>
#       3 # df = pd.concat([df,
#       4 #                 pd.read_csv("C:/Users/Mcian/Downloads/day_trader_bot/dukascopy/BTCUSD_Candlestick_1_M_BID_17.03.2018-17.03.2021.csv")])
# ----> 5 zf = zipfile.ZipFile('firstratedata/TSLA.csv')
#       6 # df = pd.read_csv(zf.open('TSLA_1min.txt'), names=['Local time', 'Open', 'High', 'Low', 'Close', 'Volume'])
#       7
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1223         try:
#    1224             if mode == 'r':
# -> 1225                 self._RealGetContents()
#    1226             elif mode in ('w', 'x'):
#    1227                 # set the modified flag so central directory gets written
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\zipfile.py in _RealGetContents(self)
#    1290             raise BadZipFile("File is not a zip file")
#    1291         if not endrec:
# -> 1292             raise BadZipFile("File is not a zip file")
#    1293         if self.debug > 1:
#    1294             print(endrec)
#
# BadZipFile: File is not a zip file

# %%
# df['Local time'] = pd.to_datetime(df['Local time'])
df['date'] = df['Local time'].apply(lambda x: x.isoformat())
df['day'] = df['Local time'].apply(lambda x: x.weekday())
df['hour'] = df['Local time'].apply(lambda x: x.hour+x.minute/60)
# del df['Local time']
df.columns = [c.lower() for c in df.columns]
df.reset_index(drop=True, inplace=True)

# %%
df = pd.read_csv('firstratedata/TSLA.csv')

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#             local time   open   high    low  close    volume  \
# 0  2011-06-30 09:30:00  5.700  5.720  5.700  5.702  256620.0
# 1  2011-06-30 09:31:00  5.708  5.734  5.700  5.724   65105.0
# 2  2011-06-30 09:32:00  5.732  5.732  5.700  5.722   16000.0
# 3  2011-06-30 09:33:00  5.722  5.722  5.718  5.718    6500.0
# 4  2011-06-30 09:34:00  5.716  5.716  5.712  5.714   17000.0
#
#    previous_day_close  previous_day_high  previous_day_low  premarket_high  \
# 0                5.79              5.798             5.666           5.702
# 1                5.79              5.798             5.666           5.702
# 2                5.79              5.798             5.666           5.702
# 3                5.79              5.798             5.666           5.702
# 4                5.79              5.798             5.666           5.702
#
#    premarket_low   tic                 date  day      hour
# 0          5.702  TSLA  2011-06-30T09:30:00    3  9.500000
# 1          5.702  TSLA  2011-06-30T09:31:00    3  9.516667
# 2          5.702  TSLA  2011-06-30T09:32:00    3  9.533333
# 3          5.702  TSLA  2011-06-30T09:33:00    3  9.550000
# 4          5.702  TSLA  2011-06-30T09:34:00    3  9.566667

# %%
df.tail()
# Out:
#                 local time      open      high       low    close   volume  \
# 71233  2021-03-22 11:27:00  692.3450  692.4400  691.5080  691.860  32875.0
# 71234  2021-03-22 11:28:00  691.9600  692.1000  690.4200  690.420  60257.0
# 71235  2021-03-22 11:29:00  690.4800  691.2113  689.8400  690.813  75871.0
# 71236  2021-03-22 11:30:00  690.8900  691.7100  690.3229  691.000  53994.0
# 71237  2021-03-22 11:31:00  690.9474  691.5000  689.9900  691.220  39766.0
#
#        previous_day_close  previous_day_high  previous_day_low  \
# 71233            642.6099              668.3          625.5387
# 71234            642.6099              668.3          625.5387
# 71235            642.6099              668.3          625.5387
# 71236            642.6099              668.3          625.5387
# 71237            642.6099              668.3          625.5387
#
#        premarket_high  premarket_low   tic                 date  day  \
# 71233          685.88          659.8  TSLA  2021-03-22T11:27:00    0
# 71234          685.88          659.8  TSLA  2021-03-22T11:28:00    0
# 71235          685.88          659.8  TSLA  2021-03-22T11:29:00    0
# 71236          685.88          659.8  TSLA  2021-03-22T11:30:00    0
# 71237          685.88          659.8  TSLA  2021-03-22T11:31:00    0
#
#             hour
# 71233  11.450000
# 71234  11.466667
# 71235  11.483333
# 71236  11.500000
# 71237  11.516667

# %%
df.shape, df.drop_duplicates().shape
# Out:
# ((71238, 15), (71238, 15))

# %%
df.sort_values(['date','tic']).head()
# Out:
#             local time   open   high    low  close    volume  \
# 0  2011-06-30 09:30:00  5.700  5.720  5.700  5.702  256620.0
# 1  2011-06-30 09:31:00  5.708  5.734  5.700  5.724   65105.0
# 2  2011-06-30 09:32:00  5.732  5.732  5.700  5.722   16000.0
# 3  2011-06-30 09:33:00  5.722  5.722  5.718  5.718    6500.0
# 4  2011-06-30 09:34:00  5.716  5.716  5.712  5.714   17000.0
#
#    previous_day_close  previous_day_high  previous_day_low  premarket_high  \
# 0                5.79              5.798             5.666           5.702
# 1                5.79              5.798             5.666           5.702
# 2                5.79              5.798             5.666           5.702
# 3                5.79              5.798             5.666           5.702
# 4                5.79              5.798             5.666           5.702
#
#    premarket_low   tic                 date  day      hour
# 0          5.702  TSLA  2011-06-30T09:30:00    3  9.500000
# 1          5.702  TSLA  2011-06-30T09:31:00    3  9.516667
# 2          5.702  TSLA  2011-06-30T09:32:00    3  9.533333
# 3          5.702  TSLA  2011-06-30T09:33:00    3  9.550000
# 4          5.702  TSLA  2011-06-30T09:34:00    3  9.566667

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
config.TSLA_TECHNICAL_INDICATORS_LIST
# Out:
# ['boll_ub',
#  'boll_lb',
#  'close_50_sma',
#  'close_200_sma',
#  'close_9_ema',
#  'close_20_ema']

# %%
columns = df.columns

# %%
columns
# Out:
# Index(['local time', 'open', 'high', 'low', 'close', 'volume',
#        'previous_day_close', 'previous_day_high', 'previous_day_low',
#        'premarket_high', 'premarket_low', 'tic', 'date', 'day', 'hour'],
#       dtype='object')

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = config.TSLA_TECHNICAL_INDICATORS_LIST,
                    use_turbulence=False,
                    user_defined_feature=True)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# Successfully added user defined features

# %%
indicators = [c for c in processed.columns if c not in columns] + ['previous_day_close', 'previous_day_high', 'previous_day_low', 'premarket_high', 'premarket_low']

# %%
indicators
# Out:
# ['boll_ub',
#  'boll_lb',
#  'close_50_sma',
#  'close_200_sma',
#  'close_9_ema',
#  'close_20_ema',
#  'vwap',
#  'previous_day_close',
#  'previous_day_high',
#  'previous_day_low',
#  'premarket_high',
#  'premarket_low']

# %%
indicators = ['boll_ub',
 'boll_lb',
 'close_50_sma',
 'close_200_sma',
 'close_9_ema',
 'close_20_ema',
 'vwap',
 'previous_day_close',
 'previous_day_high',
 'previous_day_low',
 'premarket_high',
 'premarket_low']

# %%
if False:
    list_ticker = processed["tic"].unique().tolist()
    list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
    combination = list(itertools.product(list_date,list_ticker))

    processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
    processed_full = processed_full[processed_full['date'].isin(processed['date'])]
    processed_full = processed_full.sort_values(['date','tic'])

    processed_full = processed_full.fillna(0)
else:
    processed_full = processed

# %%
processed_full.sample(5)
# Out:
#                 local time      open      high       low    close    volume  \
# 27044  2019-04-04 05:22:00   54.2000   54.2000   54.1640   54.164    7155.0
# 61094  2020-12-21 08:12:00  667.2359  667.6999  667.0000  667.200    9302.0
# 39933  2020-04-03 09:35:00  101.3680  102.4980  101.2482  102.166  585580.0
# 12798  2012-05-30 10:10:00    6.1980    6.1980    6.1840    6.184   10760.0
# 52710  2020-10-02 04:04:00  431.7400  431.7400  430.0000  430.060    4887.0
#
#        previous_day_close  previous_day_high  previous_day_low  \
# 27044             58.7520            59.2130            57.224
# 61094            661.9296           683.2956           647.060
# 39933             95.2587           100.2000            93.614
# 12798              6.3280             6.3280             6.040
# 52710            439.7400           442.5000           434.860
#
#        premarket_high  ...                 date day       hour     boll_ub  \
# 27044          55.000  ...  2019-04-04T05:22:00   3   5.366667   54.351591
# 61094         672.690  ...  2020-12-21T08:12:00   0   8.200000  669.104935
# 39933         106.200  ...  2020-04-03T09:35:00   4   9.583333  104.157142
# 12798           6.256  ...  2012-05-30T10:10:00   2  10.166667    6.201094
# 52710         435.510  ...  2020-10-02T04:04:00   4   4.066667  447.064900
#
#           boll_lb  close_50_sma  close_200_sma  close_9_ema  close_20_ema  \
# 27044   54.117009     54.262040      59.587433    54.198841     54.225660
# 61094  665.666525    668.673692     661.146873   667.078368    667.487172
# 39933  100.995058    103.260280     104.222870   102.119194    102.476451
# 12798    6.143006      6.184176       6.180988     6.181394      6.174600
# 52710  425.654740    436.742596     438.005333   432.123551    434.724443
#
#              vwap
# 27044   54.184946
# 61094  667.129347
# 39933  101.826295
# 12798    6.185055
# 52710  427.603622
#
# [5 rows x 22 columns]

# %%
if True:
    processed_full.to_csv('processed_full_TSLA.csv', index=False)

# %%
if True:    
    processed_full = pd.read_csv('processed_full_TSLA.csv')
    del processed_full['Unnamed: 0']
#     processed_full['local time'] = pd.to_datetime(processed_full['local time'])

# %%
processed_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79944 entries, 0 to 79943
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   local time     79944 non-null  object
#  1   open           79944 non-null  float64
#  2   high           79944 non-null  float64
#  3   low            79944 non-null  float64
#  4   close          79944 non-null  float64
#  5   volume         79944 non-null  float64
#  6   tic            79944 non-null  object
#  7   date           79944 non-null  object
#  8   day            79944 non-null  int64
#  9   hour           79944 non-null  float64
#  10  boll_ub        79944 non-null  float64
#  11  boll_lb        79944 non-null  float64
#  12  close_50_sma   79944 non-null  float64
#  13  close_200_sma  79944 non-null  float64
#  14  close_9_ema    79944 non-null  float64
#  15  close_20_ema   79944 non-null  float64
#  16  vwap           79944 non-null  float64
# dtypes: float64(13), int64(1), object(3)
# memory usage: 10.4+ MB

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %%
stock_dimension = len(processed_full.tic.unique())
print(f"Stock Dimension: {stock_dimension}")
# Out:
# Stock Dimension: 1

# %%
def cost_function(volume):
    return 0.01

# %%
env_kwargs = {
    "hmax": 1.0, 
    'model_name':'TSLA',
    'mode': 'train',
    "initial_amount": 50000, 
    "buy_cost_pct": cost_function, 
    "sell_cost_pct": cost_function, 
    "tech_indicator_list": indicators,
    "print_verbosity":1000,
    "terminal": True,
    "get_gif": False,
#     "minute": 71800
}

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.
#
# * In this notebook, we are training and validating 3 agents (A2C, PPO, DDPG) using Rolling-window Ensemble Method ([reference code](https://github.com/AI4Finance-LLC/Deep-Reinforcement-Learning-for-Automated-Stock-Trading-Ensemble-Strategy-ICAIF-2020/blob/80415db8fa7b2179df6bd7e81ce4fe8dbf913806/model/models.py#L92))

# %%
val_size = int(len(processed_full)*0.1)

train_start = processed_full.iloc[:-val_size]['date'].min()
train_end = processed_full.iloc[:-val_size]['date'].max()
val_test_start = processed_full.iloc[-val_size:]['date'].min()
val_test_end = processed_full.iloc[-val_size:]['date'].max()

# %%
A2C_model_kwargs = {
    'n_steps': 1,
    'ent_coef': 0.01,
    'learning_rate': 0.001,
    'device': 'cuda',
#     'gamma': 0.5
}

timesteps_dict = {
    'a2c' : 100_000, 
    'ppo' : 100_000, 
    'ddpg' : 50_000
}

# %%
processed_full.shape, processed_full[processed_full['volume'] > 0].shape
# Out:
# ((79944, 17), (79944, 17))

# %%
e_trade_gym = StockTradingEnv(processed_full.iloc[:-val_size], **env_kwargs)

# %%
import multiprocessing

n_cores = multiprocessing.cpu_count() - 2
n_cores = 24
print(f"using {n_cores} cores")

#this is our training env. It allows multiprocessing
env, _ = e_train_gym.get_multiproc_env(n = n_cores)

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib
matplotlib.interactive(False)
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import datetime

from finrl.config import config
from finrl.preprocessing.preprocessors import FeatureEngineer
from finrl.preprocessing.data import data_split
from finrl.env.env_stocktrading import StockTradingEnv
from stable_baselines.common.vec_env import SubprocVecEnv
from finrl.model.models import DRLAgent, DRLEnsembleAgent
# from finrl.trade.backtest import backtest_stats, backtest_plot, get_daily_return, get_baseline
from stable_baselines import a2c

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
import zipfile
import datetime

indicators = ['boll_ub',
 'boll_lb',
 'close_50_sma',
 'close_200_sma',
 'close_9_ema',
 'close_20_ema',
 'vwap',
 'previous_day_close',
 'previous_day_high',
 'previous_day_low',
 'premarket_high',
 'premarket_low']

if True:    
    processed_full = pd.read_csv('processed_full_TSLA.csv')

stock_dimension = len(processed_full.tic.unique())

def cost_function(volume):
    return 0.001

env_kwargs = {
    "hmax": 1.0, 
    'model_name':'TSLA',
    'mode': 'train',
    "initial_amount": 50000, 
    "buy_cost_pct": cost_function, 
    "sell_cost_pct": cost_function, 
    "tech_indicator_list": indicators,
    "print_verbosity":1000,
    "terminal": True,
    "get_gif": False,
#     "minute": 71800
}

val_size = int(len(processed_full)*0.1)

train_start = processed_full.iloc[:-val_size]['date'].min()
train_end = processed_full.iloc[:-val_size]['date'].max()
val_test_start = processed_full.iloc[-val_size:]['date'].min()
val_test_end = processed_full.iloc[-val_size:]['date'].max()

A2C_model_kwargs = {
#     'n_steps': 5,
#     'ent_coef': 0.01,
#     'learning_rate': 0.001,
#     'device': 'cuda',
#     'gamma': 0.5
}

timesteps_dict = {
    'a2c' : 100_000, 
    'ppo' : 100_000, 
    'ddpg' : 50_000
}
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
env = StockTradingEnv(processed_full.iloc[:-val_size], **env_kwargs)

# %%
agent = DRLAgent(env)

# %%
model = agent.get_model(
    'a2c',
    policy="CnnPolicy",
    verbose=0,
    model_kwargs=A2C_model_kwargs
)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.001}

# %%
total_timesteps = processed_full.iloc[:-val_size].shape[0] * 10
agent.train_model(
    model,
    tb_log_name=f"a2c/TSLA",
    total_timesteps=total_timesteps,
)
# Out:
# minute: 1000, episode: 1
# elapsed_time: 34.24544882774353
# total_steps: 930
# num_asset_resets: 0
# begin_total_asset: 50000.00
# end_total_asset: 25021.77
# total_invested: 16596.71
# total_reward: -7119.82
# total_cost: 25543.10
# total_trades: 1162
# Sharpe: -6.304
# =================================
# minute: 2000, episode: 1
# elapsed_time: 68.0286636352539
# total_steps: 1919
# num_asset_resets: 2
# begin_total_asset: 50000.00
# end_total_asset: 48426.41
# total_invested: 48424.66
# total_reward: -14547.45
# total_cost: 1594.58
# total_trades: 70
# Sharpe: -5.122
# =================================
# minute: 3000, episode: 1
# elapsed_time: 101.92942929267883
# total_steps: 2902
# num_asset_resets: 3
# begin_total_asset: 50000.00
# end_total_asset: 41113.34
# total_invested: -41495.28
# total_reward: -21311.44
# total_cost: 6540.97
# total_trades: 232
# Sharpe: -7.954
# =================================
# minute: 4000, episode: 1
# elapsed_time: 136.0009891986847
# total_steps: 3872
# num_asset_resets: 4
# begin_total_asset: 50000.00
# end_total_asset: 43596.63
# total_invested: -42776.89
# total_reward: -25485.43
# total_cost: 7197.05
# total_trades: 243
# Sharpe: -3.298
# =================================

# %%
(processed_full.iloc[:-val_size]['close'].iloc[1000] - processed_full.iloc[:-val_size]['close'].iloc[1]) / processed_full.iloc[:-val_size]['close'].iloc[1]

# %%
model.save(f"{config.TRAINED_MODEL_DIR}/TSLA_A2C_{total_timesteps // 1000}k_{total_timesteps}_iter3")

# %%
model.load(f"{config.TRAINED_MODEL_DIR}/TSLA_A2C_{100000 // 1000}k_{100000}")

# %%
val_env_a2c = StockTradingEnv(
    processed_full.iloc[-val_size:],
    model_name='TSLA',
    mode='validation',
    terminal=True,
    print_verbosity=100,
    hmax= 1.0, 
    initial_amount= 50000, 
    buy_cost_pct= cost_function, 
    sell_cost_pct= cost_function,
    tech_indicator_list= indicators,  
    get_gif=True,
)

# %%
val_obs_a2c = val_env_a2c.reset(initial_override=True)
for i in range(len(val_env_a2c.df.index.unique())):
    action, _states = model.predict(val_obs_a2c)
    test_obs, rewards, dones, info = val_env_a2c.step(action)
    if dones:
        print("hit end!")
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-5432f7891cba> in <module>
#       2 for i in range(len(val_env_a2c.df.index.unique())):
#       3     action, _states = model.predict(val_obs_a2c)
# ----> 4     test_obs, rewards, dones, info = val_env_a2c.step(action)
#       5     if dones:
#       6         print("hit end!")
#
# C:\FinRL-Library\finrl\env\env_stocktrading.py in step(self, action)
#     371         df_total_value = pd.DataFrame({'account_value': self.asset_memory, "date": self.date_memory})
#     372         df_total_value['daily_return'] = df_total_value['account_value'].pct_change(1)
# --> 373         df_total_value.dropna(inplace=True)
#     374         sharpe = 0
#     375         if df_total_value.shape[0] > 1 and df_total_value['daily_return'].iloc[-360:].std() != 0:
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    5160             agg_obj = self.take(indices, axis=agg_axis)
#    5161
# -> 5162         count = agg_obj.count(axis=agg_axis)
#    5163
#    5164         if thresh is not None:
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in count(self, axis, level, numeric_only)
#    8713             result = self._constructor_sliced(0, index=frame._get_agg_axis(axis))
#    8714         else:
# -> 8715             if frame._is_mixed_type or frame._mgr.any_extension_types:
#    8716                 # the or any_extension_types is really only hit for single-
#    8717                 # column frames with an extension array
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in _is_mixed_type(self)
#    5563             return True
#    5564
# -> 5565         return self.dtypes.nunique() > 1
#    5566
#    5567     @final
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\base.py in nunique(self, dropna)
#    1083         4
#    1084         """
# -> 1085         obj = remove_na_arraylike(self) if dropna else self
#    1086         return len(obj.unique())
#    1087
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\dtypes\missing.py in remove_na_arraylike(arr)
#     587         return arr[notna(arr)]
#     588     else:
# --> 589         return arr[notna(np.asarray(arr))]
#     590
#     591
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\dtypes\missing.py in notna(obj)
#     339     Name: 1, dtype: bool
#     340     """
# --> 341     res = isna(obj)
#     342     if is_scalar(res):
#     343         return not res
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\dtypes\missing.py in isna(obj)
#     125     Name: 1, dtype: bool
#     126     """
# --> 127     return _isna(obj)
#     128
#     129
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\dtypes\missing.py in _isna(obj, inf_as_na)
#     158         return False
#     159     elif isinstance(obj, (ABCSeries, np.ndarray, ABCIndexClass, ABCExtensionArray)):
# --> 160         return _isna_ndarraylike(obj, inf_as_na=inf_as_na)
#     161     elif isinstance(obj, ABCDataFrame):
#     162         return obj.isna()
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\dtypes\missing.py in _isna_ndarraylike(obj, inf_as_na)
#     225             result = values.isna()
#     226     elif is_string_dtype(dtype):
# --> 227         result = _isna_string_dtype(values, dtype, inf_as_na=inf_as_na)
#     228     elif needs_i8_conversion(dtype):
#     229         # this is the NaT pattern
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\dtypes\missing.py in _isna_string_dtype(values, dtype, inf_as_na)
#     257             vec = libmissing.isnaobj(values.ravel())
#     258
# --> 259         result[...] = vec.reshape(shape)
#     260
#     261     return result
#
# KeyboardInterrupt:

# %%
np.array([np.array([0]) for i in range(60-3)] + [np.array([-71.]), np.array([69.]), np.array([0.])][0-60:3]).flatten().shape
# Out:
# (60,)

# %%
val_env_a2c.minute, len(val_env_a2c.df)
# Out:
# (61, 7994)

# %%
action.flatten()
# Out:
# array([69.], dtype=float32)

# %%
model.predict(val_obs_a2c)
# Out:
# (array([1.], dtype=float32), None)

# %%
action
# Out:
# array([40.], dtype=float32)

# %%
val_env_a2c.actions_memory
# Out:
# [array([68.], dtype=float32),
#  array([66.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([66.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([71.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([71.], dtype=float32),
#  array([69.], dtype=float32),
#  array([71.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([71.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([2.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([71.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([71.], dtype=float32),
#  array([69.], dtype=float32),
#  array([71.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([71.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([2.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([71.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([71.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([69.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([70.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([67.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([66.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([63.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([1.], dtype=float32),
#  array([68.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([2.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([68.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([69.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([1.], dtype=float32),
#  array([68.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([68.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([64.], dtype=float32),
#  array([66.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([63.], dtype=float32),
#  array([65.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([66.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([65.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([64.], dtype=float32),
#  array([2.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([1.], dtype=float32),
#  array([0.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([66.], dtype=float32),
#  array([0.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  array([67.], dtype=float32),
#  array([65.], dtype=float32),
#  ...]

# %%
processed_full['local time'].iloc[0].isoformat()
# Out:
# '2018-01-05T06:30:00+07:00'

# %%
k = model.get_parameters()

# %%
k['policy'].keys()
# Out:
# odict_keys(['log_std', 'features_extractor.cnn.0.weight', 'features_extractor.cnn.0.bias', 'features_extractor.cnn.2.weight', 'features_extractor.cnn.2.bias', 'features_extractor.cnn.4.weight', 'features_extractor.cnn.4.bias', 'features_extractor.linear.0.weight', 'features_extractor.linear.0.bias', 'action_net.weight', 'action_net.bias', 'value_net.weight', 'value_net.bias'])

# %%
processed_full[[t.isoformat() == '2020-12-08T12:59:00+07:00' for t in processed_full['local time']]]
# Out:
#                        local time      open      high       low     close  \
# 263318  2020-12-08 12:59:00+07:00  1554.178  1556.988  1545.647  1545.648
#
#         volume   tic                       date  day       hour     macd  \
# 263318  0.2117  TSLA  2020-12-08T12:59:00+07:00    1  12.983333  0.97971
#
#            boll_ub     boll_lb  close_50_sma  close_200_sma  close_9_ema  \
# 263318  1554.99987  1544.16073    1546.90064    1545.374525  1549.562415
#
#         close_20_ema                       vwap
# 263318   1548.632577  2020-12-08 12:59:00+07:00

# %%
ax = processed_full.plot('date', 'close')

# %%
ax.figure.savefig('close.png')

# %%
processed_full.iloc[263318-50:263318+5]
# Out:
#                        local time      open      high       low     close  \
# 263268  2020-12-08 12:09:00+07:00  1545.587  1549.618  1545.587  1547.628
# 263269  2020-12-08 12:10:00+07:00  1547.628  1553.568  1546.608  1549.638
# 263270  2020-12-08 12:11:00+07:00  1549.638  1551.598  1548.697  1548.698
# 263271  2020-12-08 12:12:00+07:00  1546.268  1548.560  1546.248  1546.578
# 263272  2020-12-08 12:13:00+07:00  1546.648  1549.718  1545.587  1548.988
# 263273  2020-12-08 12:14:00+07:00  1549.257  1553.848  1548.987  1552.788
# 263274  2020-12-08 12:15:00+07:00  1552.787  1557.400  1552.787  1554.887
# 263275  2020-12-08 12:16:00+07:00  1554.888  1557.718  1553.427  1553.428
# 263276  2020-12-08 12:17:00+07:00  1553.868  1554.008  1549.997  1549.998
# 263277  2020-12-08 12:18:00+07:00  1549.998  1555.790  1549.997  1553.088
# 263278  2020-12-08 12:19:00+07:00  1553.088  1556.338  1553.087  1554.668
# 263279  2020-12-08 12:20:00+07:00  1553.447  1555.428  1550.997  1552.208
# 263280  2020-12-08 12:21:00+07:00  1553.197  1553.197  1545.997  1546.848
# 263281  2020-12-08 12:22:00+07:00  1546.848  1551.617  1545.997  1548.358
# 263282  2020-12-08 12:23:00+07:00  1548.358  1551.898  1548.357  1551.168
# 263283  2020-12-08 12:24:00+07:00  1551.168  1552.365  1548.218  1548.218
# 263284  2020-12-08 12:25:00+07:00  1548.628  1548.628  1545.998  1545.998
# 263285  2020-12-08 12:26:00+07:00  1547.857  1547.997  1544.997  1544.998
# 263286  2020-12-08 12:27:00+07:00  1544.998  1544.998  1541.997  1541.997
# 263287  2020-12-08 12:28:00+07:00  1541.997  1542.928  1539.997  1539.998
# 263288  2020-12-08 12:29:00+07:00  1539.997  1541.817  1535.997  1540.628
# 263289  2020-12-08 12:30:00+07:00  1541.897  1542.888  1535.997  1536.118
# 263290  2020-12-08 12:31:00+07:00  1536.118  1537.197  1532.427  1535.438
# 263291  2020-12-08 12:32:00+07:00  1536.288  1536.288  1530.997  1530.998
# 263292  2020-12-08 12:33:00+07:00  1531.287  1535.068  1530.107  1533.327
# 263293  2020-12-08 12:34:00+07:00  1535.222  1540.337  1534.448  1538.188
# 263294  2020-12-08 12:35:00+07:00  1538.188  1539.318  1535.507  1535.508
# 263295  2020-12-08 12:36:00+07:00  1535.507  1538.358  1535.108  1535.868
# 263296  2020-12-08 12:37:00+07:00  1536.168  1543.698  1534.998  1541.997
# 263297  2020-12-08 12:38:00+07:00  1541.998  1545.747  1541.287  1544.558
# 263298  2020-12-08 12:39:00+07:00  1543.508  1549.208  1541.288  1548.248
# 263299  2020-12-08 12:40:00+07:00  1548.248  1549.287  1543.678  1546.777
# 263300  2020-12-08 12:41:00+07:00  1546.977  1552.908  1546.447  1552.207
# 263301  2020-12-08 12:42:00+07:00  1552.208  1554.718  1552.017  1553.838
# 263302  2020-12-08 12:43:00+07:00  1554.368  1554.447  1550.157  1550.157
# 263303  2020-12-08 12:44:00+07:00  1550.158  1553.248  1550.157  1550.998
# 263304  2020-12-08 12:45:00+07:00  1550.998  1551.658  1544.997  1544.998
# 263305  2020-12-08 12:46:00+07:00  1546.107  1550.408  1544.997  1546.998
# 263306  2020-12-08 12:47:00+07:00  1546.998  1550.660  1546.997  1549.958
# 263307  2020-12-08 12:48:00+07:00  1549.967  1553.808  1549.307  1551.987
# 263308  2020-12-08 12:49:00+07:00  1553.377  1554.197  1546.997  1549.448
# 263309  2020-12-08 12:50:00+07:00  1548.448  1552.778  1547.767  1549.858
# 263310  2020-12-08 12:51:00+07:00  1551.098  1553.618  1549.857  1549.998
# 263311  2020-12-08 12:52:00+07:00  1549.998  1550.528  1548.207  1548.488
# 263312  2020-12-08 12:53:00+07:00  1548.647  1549.788  1547.997  1547.998
# 263313  2020-12-08 12:54:00+07:00  1547.998  1547.998  1543.567  1545.708
# 263314  2020-12-08 12:55:00+07:00  1545.708  1548.968  1544.537  1548.968
# 263315  2020-12-08 12:56:00+07:00  1548.858  1551.348  1548.287  1549.998
# 263316  2020-12-08 12:57:00+07:00  1549.997  1553.398  1549.997  1553.398
# 263317  2020-12-08 12:58:00+07:00  1552.998  1554.757  1552.147  1554.178
# 263318  2020-12-08 12:59:00+07:00  1554.178  1556.988  1545.647  1545.648
# 263319  2020-12-10 06:30:00+07:00   441.715   444.058   441.067   443.737
# 263320  2020-12-10 06:31:00+07:00   443.638   443.718   440.567   441.287
# 263321  2020-12-10 06:32:00+07:00   441.287   442.468   440.977   442.117
# 263322  2020-12-10 06:33:00+07:00   442.118   442.418   440.897   441.178
#
#            volume   tic                       date  day       hour  \
# 263268     0.0946  TSLA  2020-12-08T12:09:00+07:00    1  12.150000
# 263269     0.1006  TSLA  2020-12-08T12:10:00+07:00    1  12.166667
# 263270     0.0570  TSLA  2020-12-08T12:11:00+07:00    1  12.183333
# 263271     0.0811  TSLA  2020-12-08T12:12:00+07:00    1  12.200000
# 263272     0.0676  TSLA  2020-12-08T12:13:00+07:00    1  12.216667
# 263273     0.0961  TSLA  2020-12-08T12:14:00+07:00    1  12.233333
# 263274     0.0811  TSLA  2020-12-08T12:15:00+07:00    1  12.250000
# 263275     0.0571  TSLA  2020-12-08T12:16:00+07:00    1  12.266667
# 263276     0.0781  TSLA  2020-12-08T12:17:00+07:00    1  12.283333
# 263277     0.0796  TSLA  2020-12-08T12:18:00+07:00    1  12.300000
# 263278     0.0480  TSLA  2020-12-08T12:19:00+07:00    1  12.316667
# 263279     0.0585  TSLA  2020-12-08T12:20:00+07:00    1  12.333333
# 263280     0.0871  TSLA  2020-12-08T12:21:00+07:00    1  12.350000
# 263281     0.0631  TSLA  2020-12-08T12:22:00+07:00    1  12.366667
# 263282     0.0435  TSLA  2020-12-08T12:23:00+07:00    1  12.383333
# 263283     0.0555  TSLA  2020-12-08T12:24:00+07:00    1  12.400000
# 263284     0.0571  TSLA  2020-12-08T12:25:00+07:00    1  12.416667
# 263285     0.0751  TSLA  2020-12-08T12:26:00+07:00    1  12.433333
# 263286     0.0601  TSLA  2020-12-08T12:27:00+07:00    1  12.450000
# 263287     0.1291  TSLA  2020-12-08T12:28:00+07:00    1  12.466667
# 263288     0.0856  TSLA  2020-12-08T12:29:00+07:00    1  12.483333
# 263289     0.1261  TSLA  2020-12-08T12:30:00+07:00    1  12.500000
# 263290     0.0841  TSLA  2020-12-08T12:31:00+07:00    1  12.516667
# 263291     0.0841  TSLA  2020-12-08T12:32:00+07:00    1  12.533333
# 263292     0.1066  TSLA  2020-12-08T12:33:00+07:00    1  12.550000
# 263293     0.0916  TSLA  2020-12-08T12:34:00+07:00    1  12.566667
# 263294     0.1126  TSLA  2020-12-08T12:35:00+07:00    1  12.583333
# 263295     0.0661  TSLA  2020-12-08T12:36:00+07:00    1  12.600000
# 263296     0.0946  TSLA  2020-12-08T12:37:00+07:00    1  12.616667
# 263297     0.1186  TSLA  2020-12-08T12:38:00+07:00    1  12.633333
# 263298     0.1021  TSLA  2020-12-08T12:39:00+07:00    1  12.650000
# 263299     0.0871  TSLA  2020-12-08T12:40:00+07:00    1  12.666667
# 263300     0.1171  TSLA  2020-12-08T12:41:00+07:00    1  12.683333
# 263301     0.0976  TSLA  2020-12-08T12:42:00+07:00    1  12.700000
# 263302     0.1276  TSLA  2020-12-08T12:43:00+07:00    1  12.716667
# 263303     0.0856  TSLA  2020-12-08T12:44:00+07:00    1  12.733333
# 263304     0.1066  TSLA  2020-12-08T12:45:00+07:00    1  12.750000
# 263305     0.0751  TSLA  2020-12-08T12:46:00+07:00    1  12.766667
# 263306     0.0713  TSLA  2020-12-08T12:47:00+07:00    1  12.783333
# 263307     0.0811  TSLA  2020-12-08T12:48:00+07:00    1  12.800000
# 263308     0.1036  TSLA  2020-12-08T12:49:00+07:00    1  12.816667
# 263309     0.0751  TSLA  2020-12-08T12:50:00+07:00    1  12.833333
# 263310     0.0736  TSLA  2020-12-08T12:51:00+07:00    1  12.850000
# 263311     0.0871  TSLA  2020-12-08T12:52:00+07:00    1  12.866667
# 263312     0.0826  TSLA  2020-12-08T12:53:00+07:00    1  12.883333
# 263313     0.0796  TSLA  2020-12-08T12:54:00+07:00    1  12.900000
# 263314     0.1111  TSLA  2020-12-08T12:55:00+07:00    1  12.916667
# 263315     0.1081  TSLA  2020-12-08T12:56:00+07:00    1  12.933333
# 263316     0.1336  TSLA  2020-12-08T12:57:00+07:00    1  12.950000
# 263317     0.1276  TSLA  2020-12-08T12:58:00+07:00    1  12.966667
# 263318     0.2117  TSLA  2020-12-08T12:59:00+07:00    1  12.983333
# 263319  2040.0049  TSLA  2020-12-10T06:30:00+07:00    3   6.500000
# 263320  1860.0035  TSLA  2020-12-10T06:31:00+07:00    3   6.516667
# 263321  1507.5035  TSLA  2020-12-10T06:32:00+07:00    3   6.533333
# 263322  1995.0043  TSLA  2020-12-10T06:33:00+07:00    3   6.550000
#
#               macd      boll_ub      boll_lb  close_50_sma  close_200_sma  \
# 263268   -3.317757  1566.348719  1547.207781    1563.86054    1534.973350
# 263269   -3.451834  1566.328722  1546.291878    1563.41334    1535.221350
# 263270   -3.592528  1565.673636  1545.530964    1562.91554    1535.459850
# 263271   -3.830935  1564.977084  1544.579516    1562.34994    1535.686650
# 263272   -3.781813  1564.721870  1543.933730    1561.69214    1535.955100
# 263273   -3.397096  1564.462666  1543.779934    1561.14794    1536.236150
# 263274   -2.889524  1564.185403  1543.770097    1560.66432    1536.528100
# 263275   -2.575313  1563.895948  1543.691552    1560.19352    1536.812300
# 263276   -2.573405  1563.906303  1543.461197    1559.64932    1537.075900
# 263277   -2.296089  1563.907425  1543.463075    1559.18712    1537.349605
# 263278   -1.926612  1563.863037  1543.449463    1558.96052    1537.637955
# 263279   -1.811419  1562.719087  1543.664513    1558.60472    1537.918405
# 263280   -2.128104  1561.714804  1543.273896    1558.13172    1538.166355
# 263281   -2.231511  1559.708513  1543.816287    1557.73872    1538.427555
# 263282   -2.062938  1558.257426  1544.384374    1557.51214    1538.691460
# 263283   -2.142684  1557.472332  1544.319468    1557.30314    1538.943210
# 263284   -2.357838  1556.564313  1544.112487    1557.02954    1539.169110
# 263285   -2.579309  1556.094807  1543.581993    1556.63534    1539.393615
# 263286   -2.962828  1556.267893  1542.308907    1556.25634    1539.595910
# 263287   -3.389006  1556.988406  1541.029394    1555.83756    1539.795415
# 263288   -3.634028  1557.464724  1539.853076    1555.51178    1539.987165
# 263289   -4.144356  1558.400527  1537.565273    1554.99538    1540.158065
# 263290   -4.551202  1559.139374  1535.500426    1554.38740    1540.331215
# 263291   -5.172277  1560.437450  1532.644350    1553.57660    1540.481215
# 263292   -5.414143  1560.792179  1530.723521    1552.86320    1540.629860
# 263293   -5.154167  1560.042714  1530.012986    1552.30700    1540.779960
# 263294   -5.105534  1558.894963  1529.222837    1551.59422    1540.910515
# 263295   -4.980531  1557.758530  1528.603270    1550.93104    1541.034865
# 263296   -4.336913  1557.005644  1528.556056    1550.48782    1541.192110
# 263297   -3.578934  1555.766211  1528.942489    1550.05482    1541.369910
# 263298   -2.649931  1554.476643  1529.590057    1549.77982    1541.561165
# 263299   -2.009226  1553.486473  1530.037127    1549.53542    1541.737060
# 263300   -1.051189  1554.467127  1529.592373    1549.32240    1541.935405
# 263301   -0.158503  1555.543690  1529.063810    1549.13800    1542.161805
# 263302    0.249060  1555.357668  1529.148732    1548.98118    1542.384000
# 263303    0.632626  1555.818097  1528.966303    1548.86278    1542.598955
# 263304    0.447298  1555.718914  1528.965486    1548.60758    1542.783960
# 263305    0.456546  1555.931935  1528.952465    1548.40538    1542.969410
# 263306    0.694713  1556.738312  1528.942188    1548.36058    1543.153815
# 263307    1.035252  1557.846493  1529.032907    1548.33916    1543.355110
# 263308    1.087717  1558.463992  1529.297408    1548.22316    1543.526510
# 263309    1.149134  1558.903692  1530.231708    1547.99038    1543.703915
# 263310    1.195324  1559.150284  1531.441116    1547.77440    1543.879770
# 263311    1.097435  1558.329076  1534.011324    1547.48422    1544.056570
# 263312    0.969147  1557.465477  1536.342023    1547.24422    1544.227920
# 263313    0.674914  1557.040044  1537.519456    1547.02402    1544.380970
# 263314    0.696756  1556.001527  1539.903973    1546.86042    1544.570775
# 263315    0.788093  1554.387801  1542.930699    1546.76042    1544.760625
# 263316    1.121897  1554.409189  1544.049411    1546.76844    1544.972625
# 263317    1.432862  1554.850232  1544.570368    1546.94024    1545.199875
# 263318    0.979710  1554.999870  1544.160730    1546.90064    1545.374525
# 263319  -87.288220  1989.070371   999.786229    1524.78262    1540.027670
# 263320 -155.644710  2120.404938   757.359662    1502.63440    1534.670165
# 263321 -207.360425  2194.374457   572.218043    1480.54518    1529.295160
# 263322 -245.590259  2236.638272   419.056328    1458.38898    1523.921060
#
#         close_9_ema  close_20_ema                       vwap
# 263268  1553.228053   1556.591683  2020-12-08 12:09:00+07:00
# 263269  1552.510042   1555.929428  2020-12-08 12:10:00+07:00
# 263270  1551.747634   1555.240720  2020-12-08 12:11:00+07:00
# 263271  1550.713707   1554.415699  2020-12-08 12:12:00+07:00
# 263272  1550.368566   1553.898776  2020-12-08 12:13:00+07:00
# 263273  1550.852453   1553.792987  2020-12-08 12:14:00+07:00
# 263274  1551.659362   1553.897179  2020-12-08 12:15:00+07:00
# 263275  1552.013090   1553.852495  2020-12-08 12:16:00+07:00
# 263276  1551.610072   1553.485401  2020-12-08 12:17:00+07:00
# 263277  1551.905657   1553.447553  2020-12-08 12:18:00+07:00
# 263278  1552.458126   1553.563786  2020-12-08 12:19:00+07:00
# 263279  1552.408101   1553.434664  2020-12-08 12:20:00+07:00
# 263280  1551.296081   1552.807362  2020-12-08 12:21:00+07:00
# 263281  1550.708464   1552.383613  2020-12-08 12:22:00+07:00
# 263282  1550.800372   1552.267841  2020-12-08 12:23:00+07:00
# 263283  1550.283897   1551.882142  2020-12-08 12:24:00+07:00
# 263284  1549.426718   1551.321747  2020-12-08 12:25:00+07:00
# 263285  1548.540974   1550.719486  2020-12-08 12:26:00+07:00
# 263286  1547.232179   1549.888773  2020-12-08 12:27:00+07:00
# 263287  1545.785344   1548.946794  2020-12-08 12:28:00+07:00
# 263288  1544.753875   1548.154528  2020-12-08 12:29:00+07:00
# 263289  1543.026700   1547.008192  2020-12-08 12:30:00+07:00
# 263290  1541.508960   1545.906269  2020-12-08 12:31:00+07:00
# 263291  1539.406768   1544.486434  2020-12-08 12:32:00+07:00
# 263292  1538.190814   1543.423631  2020-12-08 12:33:00+07:00
# 263293  1538.190251   1542.924999  2020-12-08 12:34:00+07:00
# 263294  1537.653801   1542.218618  2020-12-08 12:35:00+07:00
# 263295  1537.296641   1541.613798  2020-12-08 12:36:00+07:00
# 263296  1538.236713   1541.650293  2020-12-08 12:37:00+07:00
# 263297  1539.500970   1541.927217  2020-12-08 12:38:00+07:00
# 263298  1541.250376   1542.529197  2020-12-08 12:39:00+07:00
# 263299  1542.355701   1542.933749  2020-12-08 12:40:00+07:00
# 263300  1544.325961   1543.816916  2020-12-08 12:41:00+07:00
# 263301  1546.228369   1544.771305  2020-12-08 12:42:00+07:00
# 263302  1547.014095   1545.284228  2020-12-08 12:43:00+07:00
# 263303  1547.810876   1545.828397  2020-12-08 12:44:00+07:00
# 263304  1547.248301   1545.749312  2020-12-08 12:45:00+07:00
# 263305  1547.198241   1545.868234  2020-12-08 12:46:00+07:00
# 263306  1547.750192   1546.257736  2020-12-08 12:47:00+07:00
# 263307  1548.597554   1546.803380  2020-12-08 12:48:00+07:00
# 263308  1548.767643   1547.055249  2020-12-08 12:49:00+07:00
# 263309  1548.985715   1547.322177  2020-12-08 12:50:00+07:00
# 263310  1549.188172   1547.577018  2020-12-08 12:51:00+07:00
# 263311  1549.048137   1547.663778  2020-12-08 12:52:00+07:00
# 263312  1548.838110   1547.695609  2020-12-08 12:53:00+07:00
# 263313  1548.212088   1547.506312  2020-12-08 12:54:00+07:00
# 263314  1548.363270   1547.645521  2020-12-08 12:55:00+07:00
# 263315  1548.690216   1547.869566  2020-12-08 12:56:00+07:00
# 263316  1549.631773   1548.396084  2020-12-08 12:57:00+07:00
# 263317  1550.541018   1548.946743  2020-12-08 12:58:00+07:00
# 263318  1549.562415   1548.632577  2020-12-08 12:59:00+07:00
# 263319  1328.397332   1443.404426  2020-12-10 06:30:00+07:00
# 263320  1150.975265   1347.964672  2020-12-10 06:31:00+07:00
# 263321  1009.203612   1261.693465  2020-12-10 06:32:00+07:00
# 263322   895.598490   1183.549135  2020-12-10 06:33:00+07:00

# %%
processed_full.iloc[-val_size:]
# Out:
#                        local time     open     high      low    close  \
# 292290  2021-12-03 12:10:00+08:00  686.308  686.308  684.638  684.807
# 292291  2021-12-03 12:11:00+08:00  684.807  684.968  684.047  684.737
# 292292  2021-12-03 12:12:00+08:00  684.872  686.447  684.778  686.037
# 292293  2021-12-03 12:13:00+08:00  686.038  686.038  685.458  685.567
# 292294  2021-12-03 12:14:00+08:00  685.568  686.427  685.087  685.438
# 292295  2021-12-03 12:15:00+08:00  685.437  686.037  684.537  685.877
# 292296  2021-12-03 12:16:00+08:00  685.877  685.937  684.777  685.598
# 292297  2021-12-03 12:17:00+08:00  685.737  685.968  685.277  685.848
# 292298  2021-12-03 12:18:00+08:00  685.848  686.708  685.848  686.387
# 292299  2021-12-03 12:19:00+08:00  686.388  686.898  686.267  686.877
# 292300  2021-12-03 12:20:00+08:00  686.878  687.818  686.547  687.818
# 292301  2021-12-03 12:21:00+08:00  687.617  688.857  687.247  688.358
# 292302  2021-12-03 12:22:00+08:00  688.347  689.558  688.347  688.987
# 292303  2021-12-03 12:23:00+08:00  688.988  689.057  688.497  688.557
# 292304  2021-12-03 12:24:00+08:00  688.558  688.558  687.728  688.517
# 292305  2021-12-03 12:25:00+08:00  688.387  688.557  687.867  688.147
# 292306  2021-12-03 12:26:00+08:00  688.147  688.978  688.017  688.858
# 292307  2021-12-03 12:27:00+08:00  688.918  689.598  688.857  688.858
# 292308  2021-12-03 12:28:00+08:00  688.888  688.968  688.447  688.507
# 292309  2021-12-03 12:29:00+08:00  688.508  688.698  687.997  688.467
# 292310  2021-12-03 12:30:00+08:00  688.457  688.998  688.028  688.368
# 292311  2021-12-03 12:31:00+08:00  688.387  689.038  688.248  688.687
# 292312  2021-12-03 12:32:00+08:00  688.747  688.907  688.247  688.427
# 292313  2021-12-03 12:33:00+08:00  688.327  689.008  688.048  688.338
# 292314  2021-12-03 12:34:00+08:00  688.188  688.587  687.738  688.097
# 292315  2021-12-03 12:35:00+08:00  688.078  689.027  687.928  689.017
# 292316  2021-12-03 12:36:00+08:00  689.017  690.197  688.747  690.047
# 292317  2021-12-03 12:37:00+08:00  690.017  690.327  689.497  689.907
# 292318  2021-12-03 12:38:00+08:00  690.017  690.548  688.867  690.098
# 292319  2021-12-03 12:39:00+08:00  690.107  690.375  689.878  690.177
# 292320  2021-12-03 12:40:00+08:00  690.157  690.588  689.997  690.278
# 292321  2021-12-03 12:41:00+08:00  690.307  690.427  689.557  689.688
# 292322  2021-12-03 12:42:00+08:00  689.688  690.398  689.528  690.328
# 292323  2021-12-03 12:43:00+08:00  690.327  692.178  690.287  690.648
# 292324  2021-12-03 12:44:00+08:00  690.737  691.997  690.697  691.408
# 292325  2021-12-03 12:45:00+08:00  691.408  691.678  690.687  690.727
# 292326  2021-12-03 12:46:00+08:00  690.727  691.117  690.367  690.727
# 292327  2021-12-03 12:47:00+08:00  690.698  691.148  690.578  691.038
# 292328  2021-12-03 12:48:00+08:00  691.038  691.088  690.427  690.947
# 292329  2021-12-03 12:49:00+08:00  690.948  691.867  690.837  691.627
# 292330  2021-12-03 12:50:00+08:00  691.658  691.658  690.288  690.617
# 292331  2021-12-03 12:51:00+08:00  690.617  690.978  690.428  690.608
# 292332  2021-12-03 12:52:00+08:00  690.608  690.938  690.348  690.877
# 292333  2021-12-03 12:53:00+08:00  690.887  692.168  690.887  691.968
# 292334  2021-12-03 12:54:00+08:00  691.948  692.707  691.868  692.328
# 292335  2021-12-03 12:55:00+08:00  692.377  694.258  692.377  694.255
# 292336  2021-12-03 12:56:00+08:00  694.188  694.727  693.027  693.238
# 292337  2021-12-03 12:57:00+08:00  693.237  693.498  693.007  693.147
# 292338  2021-12-03 12:58:00+08:00  693.168  693.387  692.347  692.898
# 292339  2021-12-03 12:59:00+08:00  692.947  694.037  692.307  693.818
#
#          volume   tic                       date  day       hour      macd  \
# 292290  20.5330  TSLA  2021-12-03T12:10:00+08:00    4  12.166667 -0.456420
# 292291  17.8205  TSLA  2021-12-03T12:11:00+08:00    4  12.183333 -0.569058
# 292292  22.0735  TSLA  2021-12-03T12:12:00+08:00    4  12.200000 -0.547120
# 292293  12.8389  TSLA  2021-12-03T12:13:00+08:00    4  12.216667 -0.561189
# 292294  16.7209  TSLA  2021-12-03T12:14:00+08:00    4  12.233333 -0.576107
# 292295  12.6903  TSLA  2021-12-03T12:15:00+08:00    4  12.250000 -0.546210
# 292296  15.2552  TSLA  2021-12-03T12:16:00+08:00    4  12.266667 -0.538818
# 292297  14.3744  TSLA  2021-12-03T12:17:00+08:00    4  12.283333 -0.506943
# 292298  20.9776  TSLA  2021-12-03T12:18:00+08:00    4  12.300000 -0.433196
# 292299  14.9657  TSLA  2021-12-03T12:19:00+08:00    4  12.316667 -0.331391
# 292300  17.1594  TSLA  2021-12-03T12:20:00+08:00    4  12.333333 -0.172788
# 292301  22.1450  TSLA  2021-12-03T12:21:00+08:00    4  12.350000 -0.003480
# 292302  20.6817  TSLA  2021-12-03T12:22:00+08:00    4  12.366667  0.179385
# 292303  15.9133  TSLA  2021-12-03T12:23:00+08:00    4  12.383333  0.286309
# 292304  22.8087  TSLA  2021-12-03T12:24:00+08:00    4  12.400000  0.363627
# 292305  16.8696  TSLA  2021-12-03T12:25:00+08:00    4  12.416667  0.390545
# 292306  18.9951  TSLA  2021-12-03T12:26:00+08:00    4  12.433333  0.463902
# 292307  16.5018  TSLA  2021-12-03T12:27:00+08:00    4  12.450000  0.516088
# 292308  17.4525  TSLA  2021-12-03T12:28:00+08:00    4  12.466667  0.523094
# 292309  20.4648  TSLA  2021-12-03T12:29:00+08:00    4  12.483333  0.519431
# 292310  18.1161  TSLA  2021-12-03T12:30:00+08:00    4  12.500000  0.502744
# 292311  19.4328  TSLA  2021-12-03T12:31:00+08:00    4  12.516667  0.509388
# 292312  22.1458  TSLA  2021-12-03T12:32:00+08:00    4  12.533333  0.488047
# 292313  22.3666  TSLA  2021-12-03T12:33:00+08:00    4  12.550000  0.458666
# 292314  20.3129  TSLA  2021-12-03T12:34:00+08:00    4  12.566667  0.411195
# 292315  25.7416  TSLA  2021-12-03T12:35:00+08:00    4  12.583333  0.442707
# 292316  28.1602  TSLA  2021-12-03T12:36:00+08:00    4  12.600000  0.544515
# 292317  26.3281  TSLA  2021-12-03T12:37:00+08:00    4  12.616667  0.606907
# 292318  22.7347  TSLA  2021-12-03T12:38:00+08:00    4  12.633333  0.664109
# 292319  14.5958  TSLA  2021-12-03T12:39:00+08:00    4  12.650000  0.707659
# 292320  24.8620  TSLA  2021-12-03T12:40:00+08:00    4  12.666667  0.741772
# 292321  20.4621  TSLA  2021-12-03T12:41:00+08:00    4  12.683333  0.712981
# 292322  18.1168  TSLA  2021-12-03T12:42:00+08:00    4  12.700000  0.733352
# 292323  25.5928  TSLA  2021-12-03T12:43:00+08:00    4  12.716667  0.766482
# 292324  28.6015  TSLA  2021-12-03T12:44:00+08:00    4  12.733333  0.844330
# 292325  24.8626  TSLA  2021-12-03T12:45:00+08:00    4  12.750000  0.841376
# 292326  21.7089  TSLA  2021-12-03T12:46:00+08:00    4  12.766667  0.829473
# 292327  26.6213  TSLA  2021-12-03T12:47:00+08:00    4  12.783333  0.835504
# 292328  26.8433  TSLA  2021-12-03T12:48:00+08:00    4  12.800000  0.823448
# 292329  26.9872  TSLA  2021-12-03T12:49:00+08:00    4  12.816667  0.858864
# 292330  22.7346  TSLA  2021-12-03T12:50:00+08:00    4  12.833333  0.796254
# 292331  17.6730  TSLA  2021-12-03T12:51:00+08:00    4  12.850000  0.737408
# 292332  18.1154  TSLA  2021-12-03T12:52:00+08:00    4  12.866667  0.704359
# 292333  23.9818  TSLA  2021-12-03T12:53:00+08:00    4  12.883333  0.757471
# 292334  22.4390  TSLA  2021-12-03T12:54:00+08:00    4  12.900000  0.819168
# 292335  28.8938  TSLA  2021-12-03T12:55:00+08:00    4  12.916667  1.011892
# 292336  31.6036  TSLA  2021-12-03T12:56:00+08:00    4  12.933333  1.070227
# 292337  26.9112  TSLA  2021-12-03T12:57:00+08:00    4  12.950000  1.096475
# 292338  22.7338  TSLA  2021-12-03T12:58:00+08:00    4  12.966667  1.084681
# 292339  26.1728  TSLA  2021-12-03T12:59:00+08:00    4  12.983333  1.136470
#
#            boll_ub     boll_lb  close_50_sma  close_200_sma  close_9_ema  \
# 292290  691.282400  684.102000     686.48460     687.740535   686.313833
# 292291  691.281114  683.706186     686.54040     687.721085   685.998466
# 292292  691.061732  683.593468     686.60758     687.705530   686.006173
# 292293  690.569667  683.589433     686.65136     687.691980   685.918338
# 292294  690.057392  683.618808     686.69978     687.682530   685.822271
# 292295  689.667655  683.655445     686.76678     687.676275   685.833217
# 292296  689.337224  683.652976     686.82740     687.669875   685.786173
# 292297  688.861889  683.787411     686.90080     687.661230   685.798539
# 292298  688.194712  684.136488     686.96240     687.653325   685.916231
# 292299  687.498206  684.591994     687.02118     687.649825   686.108385
# 292300  687.485772  684.600428     687.09458     687.647625   686.450308
# 292301  687.889750  684.367450     687.18060     687.652380   686.831846
# 292302  688.450936  684.152164     687.28180     687.662130   687.262877
# 292303  688.797041  684.068959     687.34618     687.668025   687.521702
# 292304  689.084042  684.067858     687.41078     687.675020   687.720761
# 292305  689.269958  684.080842     687.45616     687.678765   687.806009
# 292306  689.566144  684.036656     687.51236     687.674565   688.016407
# 292307  689.829251  684.022549     687.56258     687.658565   688.184726
# 292308  689.993995  684.017805     687.62196     687.643560   688.249181
# 292309  690.151515  684.073185     687.66616     687.631110   688.292744
# 292310  690.174164  684.406636     687.71296     687.620160   688.307796
# 292311  690.169297  684.806503     687.75254     687.608410   688.383636
# 292312  690.228897  684.985903     687.76934     687.590310   688.392309
# 292313  690.201011  685.290889     687.79334     687.567360   688.381447
# 292314  690.082862  685.674938     687.77692     687.543160   688.324558
# 292315  690.081052  685.990748     687.78770     687.520260   688.463046
# 292316  690.148995  686.367705     687.79868     687.505505   688.779837
# 292317  690.119678  686.802922     687.81448     687.497405   689.005270
# 292318  690.151301  687.142399     687.81808     687.487760   689.223816
# 292319  690.219761  687.403939     687.82108     687.480105   689.414453
# 292320  690.405603  687.464097     687.85450     687.469960   689.587162
# 292321  690.482518  687.520182     687.87410     687.455765   689.607330
# 292322  690.663835  687.472965     687.89350     687.448715   689.751464
# 292323  690.896209  687.449691     687.89590     687.448670   689.930771
# 292324  691.277789  687.357211     687.91872     687.453475   690.226217
# 292325  691.421970  687.471030     687.94510     687.454420   690.326373
# 292326  691.574156  687.505744     687.98110     687.457265   690.406499
# 292327  691.761417  687.536483     688.01672     687.456620   690.532799
# 292328  691.887559  687.654341     688.04430     687.449420   690.615639
# 292329  692.106612  687.751288     688.09110     687.444070   690.817911
# 292330  692.109171  687.973629     688.14628     687.429265   690.777729
# 292331  692.116902  688.157998     688.22548     687.410820   690.743783
# 292332  692.091415  688.428485     688.33246     687.395465   690.770427
# 292333  692.188475  688.694425     688.45326     687.396365   691.009941
# 292334  692.220097  689.085903     688.58666     687.398670   691.273553
# 292335  692.996958  688.832842     688.74860     687.416705   691.869842
# 292336  693.355978  688.792922     688.88660     687.429710   692.143474
# 292337  693.626480  688.846420     689.02218     687.444755   692.344179
# 292338  693.813265  688.939635     689.14200     687.448255   692.454943
# 292339  694.156697  688.960303     689.29160     687.456610   692.727555
#
#         close_20_ema                       vwap
# 292290    686.960334  2021-12-03 12:10:00+08:00
# 292291    686.748588  2021-12-03 12:11:00+08:00
# 292292    686.680818  2021-12-03 12:12:00+08:00
# 292293    686.574740  2021-12-03 12:13:00+08:00
# 292294    686.466479  2021-12-03 12:14:00+08:00
# 292295    686.410338  2021-12-03 12:15:00+08:00
# 292296    686.332973  2021-12-03 12:16:00+08:00
# 292297    686.286785  2021-12-03 12:17:00+08:00
# 292298    686.296329  2021-12-03 12:18:00+08:00
# 292299    686.351631  2021-12-03 12:19:00+08:00
# 292300    686.491285  2021-12-03 12:20:00+08:00
# 292301    686.669068  2021-12-03 12:21:00+08:00
# 292302    686.889823  2021-12-03 12:22:00+08:00
# 292303    687.048602  2021-12-03 12:23:00+08:00
# 292304    687.188449  2021-12-03 12:24:00+08:00
# 292305    687.279740  2021-12-03 12:25:00+08:00
# 292306    687.430050  2021-12-03 12:26:00+08:00
# 292307    687.566045  2021-12-03 12:27:00+08:00
# 292308    687.655660  2021-12-03 12:28:00+08:00
# 292309    687.732931  2021-12-03 12:29:00+08:00
# 292310    687.793413  2021-12-03 12:30:00+08:00
# 292311    687.878517  2021-12-03 12:31:00+08:00
# 292312    687.930753  2021-12-03 12:32:00+08:00
# 292313    687.969539  2021-12-03 12:33:00+08:00
# 292314    687.981678  2021-12-03 12:34:00+08:00
# 292315    688.080280  2021-12-03 12:35:00+08:00
# 292316    688.267587  2021-12-03 12:36:00+08:00
# 292317    688.423721  2021-12-03 12:37:00+08:00
# 292318    688.583176  2021-12-03 12:38:00+08:00
# 292319    688.734969  2021-12-03 12:39:00+08:00
# 292320    688.881924  2021-12-03 12:40:00+08:00
# 292321    688.958694  2021-12-03 12:41:00+08:00
# 292322    689.089104  2021-12-03 12:42:00+08:00
# 292323    689.237570  2021-12-03 12:43:00+08:00
# 292324    689.444278  2021-12-03 12:44:00+08:00
# 292325    689.566442  2021-12-03 12:45:00+08:00
# 292326    689.676971  2021-12-03 12:46:00+08:00
# 292327    689.806593  2021-12-03 12:47:00+08:00
# 292328    689.915203  2021-12-03 12:48:00+08:00
# 292329    690.078231  2021-12-03 12:49:00+08:00
# 292330    690.129543  2021-12-03 12:50:00+08:00
# 292331    690.175110  2021-12-03 12:51:00+08:00
# 292332    690.241957  2021-12-03 12:52:00+08:00
# 292333    690.406342  2021-12-03 12:53:00+08:00
# 292334    690.589357  2021-12-03 12:54:00+08:00
# 292335    690.938466  2021-12-03 12:55:00+08:00
# 292336    691.157469  2021-12-03 12:56:00+08:00
# 292337    691.346948  2021-12-03 12:57:00+08:00
# 292338    691.494667  2021-12-03 12:58:00+08:00
# 292339    691.715937  2021-12-03 12:59:00+08:00

# %%
from gym.stable_baselines3.common.models import register
@register("ResNet50")
def ResNet50():
    return tf.keras.applications.ResNet50(weights=None, input_shape=(720, 720, 3))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-39-9953aafb25c1> in <module>
# ----> 1 from gym.stable_baselines3.common.models import register
#       2 @register("ResNet50")
#       3 def ResNet50():
#       4     return tf.keras.applications.ResNet50(weights=None, input_shape=(720, 720, 3))
#
# ModuleNotFoundError: No module named 'gym.stable_baselines3'

# %%
test_env, test_obs = env.get_sb_env()
"""make a prediction"""
account_memory = []
actions_memory = []
test_env.reset()
# for i in range(len(env.df.index.unique())):
for i in range(100):
    action, _states = model.predict(test_obs)
    # account_memory = test_env.env_method(method_name="save_asset_memory")
    # actions_memory = test_env.env_method(method_name="save_action_memory")
    test_obs, rewards, dones, info = test_env.step(action)
    print(action, rewards)
    if i == (len(env.df.index.unique()) - 2):
        account_memory = test_env.env_method(method_name="save_asset_memory")
        actions_memory = test_env.env_method(method_name="save_action_memory")
    if dones[0]:
        print("hit end!")
        break
# Out:
# [[1.]] [-0.04734009]
# [[1.]] [0.00023923]
# [[-0.84509784]] [0.00770927]
# [[0.8091968]] [-0.00272402]
# [[1.]] [-0.00958214]
# [[0.28229555]] [-0.00283352]
# [[-1.]] [0.00172282]
# [[-1.]] [0.00120054]
# [[-0.5244205]] [-0.002283]
# [[-0.23109587]] [0.001903]
# [[1.]] [-0.00023343]
# [[-0.4049254]] [-0.01059501]
# [[0.11872016]] [0.00199416]
# [[-1.]] [0.00863926]
# [[0.12077695]] [-0.00897609]
# [[-1.]] [0.0010336]
# [[0.9239363]] [0.00108594]
# [[0.9348559]] [-0.00670834]
# [[-0.71991146]] [-0.00849424]
# [[0.6444769]] [-0.00031028]
# [[0.42198166]] [0.00379469]
# [[1.]] [-0.01336666]
# [[-0.6620392]] [0.00114149]
# [[-1.]] [-0.00588858]
# [[1.]] [0.00455282]
# [[0.06904575]] [-0.00680863]
# [[1.]] [-1.6649057e-05]
# [[1.]] [-0.00166566]
# [[1.]] [-0.0041625]
# [[0.1891369]] [-0.00299698]
# [[-0.39801818]] [-0.00760333]
# [[-1.]] [0.01078729]
# [[0.1984188]] [-0.00568054]
# [[1.]] [-0.00613895]
# [[-1.]] [-0.00108998]
# [[-1.]] [-0.00110173]
# [[0.92590463]] [-0.00383831]
# [[1.]] [0.00193718]
# [[-0.638623]] [0.00547628]
# [[-0.90779054]] [0.00022484]
# [[1.]] [0.00193705]
# [[0.4737678]] [-0.00301918]
# [[-0.6939412]] [-0.00680577]
# [[-1.]] [0.004664]
# [[-0.75776935]] [0.00403717]
# [[-0.8362455]] [-0.00137642]
# [[1.]] [-0.00019085]
# [[-0.9300932]] [-0.00902246]
# [[0.21996585]] [-0.00337236]
# [[0.3613268]] [0.00570714]
# [[1.]] [0.00319853]
# [[0.86419165]] [0.01112185]
# [[0.41500455]] [0.01014527]
# [[-1.]] [-0.01233612]
# [[0.24626672]] [-0.00090963]
# [[-1.]] [0.00220642]
# [[0.34244257]] [0.00114574]
# [[1.]] [0.00402678]
# [[0.7980924]] [0.00296629]
# [[0.28320372]] [0.00034835]
# [[1.]] [0.00781339]
# [[-0.9458329]] [-0.00425149]
# [[-1.]] [-0.00914388]
# [[-0.70253575]] [0.00617398]
# [[-1.]] [-0.0064514]
# [[0.01898963]] [0.00354889]
# [[-0.67502666]] [0.00453207]
# [[1.]] [-0.00628699]
# [[0.7758094]] [0.00214148]
# [[1.]] [0.0052903]
# [[-1.]] [-0.00127222]
# [[-0.38710475]] [0.00271093]
# [[-1.]] [-0.00257591]
# [[-1.]] [-0.00076963]
# [[0.03020949]] [-0.00067934]
# [[1.]] [-0.00750954]
# [[0.02028812]] [0.00033133]
# [[0.03484492]] [-0.00265762]
# [[0.7235415]] [0.00095591]
# [[0.9357002]] [-0.00432918]
# [[-0.42350626]] [0.00205263]
# [[-0.75091106]] [0.00077988]
# [[-1.]] [0.00218104]
# [[1.]] [-0.00108836]
# [[0.6035416]] [-0.00182415]
# [[0.14897937]] [0.00147658]
# [[-1.]] [-0.00490358]
# [[-1.]] [-0.00157686]
# [[-1.]] [-0.00143871]
# [[1.]] [0.00320067]
# [[0.81192046]] [0.00277952]
# [[-0.1132087]] [0.00662145]
# [[1.]] [0.00428005]
# [[0.01802063]] [0.00114565]
# [[-0.12131845]] [0.00212294]
# [[0.6951601]] [0.00065731]
# [[-0.12294424]] [-0.00187589]
# [[-0.34107512]] [0.00141081]
# [[-0.35891986]] [-0.00489227]
# [[-0.4115467]] [0.00118663]

# %%
matplotlib.use('Qt5Agg')
plt.figure(figsize=(12,12))
plt.imshow(test_obs[0])
plt.axis('off')
plt.show()

# %%
from finrl.env.env_stocktrading import get_fig

# %%
get_fig(processed_full, 60, 60)

# %%
test_env, test_obs = env.get_sb_env()

# %%
action, _states = model.predict(test_obs)

# %%
_states

# %%
account, actions = agent.DRL_prediction(model, env)

# %%
model = model.learn(total_timesteps=5000, tb_log_name=tb_log_name)
model.save(f"{config.TRAINED_MODEL_DIR}/{model_name.upper()}_{total_timesteps // 1000}k_{iter_num}")

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# ======Model training from:  2017-01-06T00:00:00+07:00 to  2020-10-27T17:01:00+07:00
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0005}
# Using cuda device
# Logging to tensorboard_log/a2c\a2c_126_11
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 100      |
# |    time_elapsed       | 74       |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -1.45    |
# |    explained_variance | -88.7    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.193   |
# |    std                | 1.03     |
# |    value_loss         | 0.0128   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 200      |
# |    time_elapsed       | 149      |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.47    |
# |    explained_variance | -139     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 199      |
# |    policy_loss        | -0.072   |
# |    std                | 1.05     |
# |    value_loss         | 0.00887  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 300      |
# |    time_elapsed       | 224      |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -1.48    |
# |    explained_variance | -206     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 299      |
# |    policy_loss        | 0.018    |
# |    std                | 1.06     |
# |    value_loss         | 0.00351  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 400      |
# |    time_elapsed       | 298      |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -1.49    |
# |    explained_variance | -560     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 399      |
# |    policy_loss        | -0.0511  |
# |    std                | 1.08     |
# |    value_loss         | 0.00176  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 500      |
# |    time_elapsed       | 372      |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -1.51    |
# |    explained_variance | -67.7    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.0206  |
# |    std                | 1.1      |
# |    value_loss         | 0.000842 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 600      |
# |    time_elapsed       | 447      |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -1.54    |
# |    explained_variance | -0.375   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0882  |
# |    std                | 1.13     |
# |    value_loss         | 0.00428  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 700      |
# |    time_elapsed       | 521      |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | -0.529   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0365  |
# |    std                | 1.15     |
# |    value_loss         | 0.00112  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 800      |
# |    time_elapsed       | 596      |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | -66.2    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 799      |
# |    policy_loss        | 0.0253   |
# |    std                | 1.17     |
# |    value_loss         | 0.000365 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 900      |
# |    time_elapsed       | 670      |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | -26.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 899      |
# |    policy_loss        | 0.0788   |
# |    std                | 1.19     |
# |    value_loss         | 0.00257  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 1000     |
# |    time_elapsed       | 744      |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -1.61    |
# |    explained_variance | -1.56    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.001    |
# |    std                | 1.21     |
# |    value_loss         | 1.49e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 1100     |
# |    time_elapsed       | 819      |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -1.64    |
# |    explained_variance | -4.29    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1099     |
# |    policy_loss        | -0.00317 |
# |    std                | 1.25     |
# |    value_loss         | 1.48e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 1200     |
# |    time_elapsed       | 893      |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -1.67    |
# |    explained_variance | -14.6    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.0991   |
# |    std                | 1.28     |
# |    value_loss         | 0.00474  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 1300     |
# |    time_elapsed       | 967      |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -1.69    |
# |    explained_variance | -127     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.002   |
# |    std                | 1.31     |
# |    value_loss         | 0.000764 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 1400      |
# |    time_elapsed       | 1042      |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -1.71     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.00138  |
# |    std                | 1.34      |
# |    value_loss         | 3.66e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 1500     |
# |    time_elapsed       | 1117     |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -1.74    |
# |    explained_variance | -1.01    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.0119  |
# |    std                | 1.37     |
# |    value_loss         | 0.000145 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 1600      |
# |    time_elapsed       | 1192      |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 1599      |
# |    policy_loss        | 0.00746   |
# |    std                | 1.41      |
# |    value_loss         | 2.25e-05  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 1700     |
# |    time_elapsed       | 1267     |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -1.78    |
# |    explained_variance | -1.53    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.0172  |
# |    std                | 1.44     |
# |    value_loss         | 4.32e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 1800     |
# |    time_elapsed       | 1341     |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.81    |
# |    explained_variance | 0.391    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1799     |
# |    policy_loss        | 0.0277   |
# |    std                | 1.48     |
# |    value_loss         | 0.000317 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 1900     |
# |    time_elapsed       | 1416     |
# |    total_timesteps    | 9500     |
# | train/                |          |
# |    entropy_loss       | -1.84    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.00218 |
# |    std                | 1.52     |
# |    value_loss         | 1.53e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2000     |
# |    time_elapsed       | 1490     |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -1.87    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.00138  |
# |    std                | 1.57     |
# |    value_loss         | 6.66e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2100     |
# |    time_elapsed       | 1565     |
# |    total_timesteps    | 10500    |
# | train/                |          |
# |    entropy_loss       | -1.89    |
# |    explained_variance | -0.521   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.00729 |
# |    std                | 1.6      |
# |    value_loss         | 6.65e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2200     |
# |    time_elapsed       | 1639     |
# |    total_timesteps    | 11000    |
# | train/                |          |
# |    entropy_loss       | -1.92    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2199     |
# |    policy_loss        | 0.00389  |
# |    std                | 1.64     |
# |    value_loss         | 5.98e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2300     |
# |    time_elapsed       | 1713     |
# |    total_timesteps    | 11500    |
# | train/                |          |
# |    entropy_loss       | -1.95    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.000252 |
# |    std                | 1.7      |
# |    value_loss         | 3.67e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2400     |
# |    time_elapsed       | 1787     |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -1.98    |
# |    explained_variance | -0.468   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2399     |
# |    policy_loss        | -0.0037  |
# |    std                | 1.75     |
# |    value_loss         | 3.05e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2500     |
# |    time_elapsed       | 1862     |
# |    total_timesteps    | 12500    |
# | train/                |          |
# |    entropy_loss       | -2.02    |
# |    explained_variance | -176     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.0387  |
# |    std                | 1.82     |
# |    value_loss         | 0.000951 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2600     |
# |    time_elapsed       | 1936     |
# |    total_timesteps    | 13000    |
# | train/                |          |
# |    entropy_loss       | -2.06    |
# |    explained_variance | -3.26    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.0103  |
# |    std                | 1.91     |
# |    value_loss         | 3.68e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2700     |
# |    time_elapsed       | 2010     |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -2.09    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.000706 |
# |    std                | 1.97     |
# |    value_loss         | 1.53e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2800     |
# |    time_elapsed       | 2084     |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -2.13    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.0235   |
# |    std                | 2.05     |
# |    value_loss         | 9.81e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 2900     |
# |    time_elapsed       | 2159     |
# |    total_timesteps    | 14500    |
# | train/                |          |
# |    entropy_loss       | -2.17    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.00215  |
# |    std                | 2.12     |
# |    value_loss         | 1.67e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 3000     |
# |    time_elapsed       | 2233     |
# |    total_timesteps    | 15000    |
# | train/                |          |
# |    entropy_loss       | -2.2     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.00176  |
# |    std                | 2.18     |
# |    value_loss         | 8.84e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 3100     |
# |    time_elapsed       | 2307     |
# |    total_timesteps    | 15500    |
# | train/                |          |
# |    entropy_loss       | -2.24    |
# |    explained_variance | -5.15    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0151  |
# |    std                | 2.26     |
# |    value_loss         | 1.8e-05  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3200      |
# |    time_elapsed       | 2382      |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -2.28     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 3199      |
# |    policy_loss        | 0.00352   |
# |    std                | 2.36      |
# |    value_loss         | 3.62e-06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 3300     |
# |    time_elapsed       | 2456     |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -2.32    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3299     |
# |    policy_loss        | 0.0013   |
# |    std                | 2.47     |
# |    value_loss         | 2.92e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 3400     |
# |    time_elapsed       | 2530     |
# |    total_timesteps    | 17000    |
# | train/                |          |
# |    entropy_loss       | -2.37    |
# |    explained_variance | -1.6     |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3399     |
# |    policy_loss        | 0.0218   |
# |    std                | 2.59     |
# |    value_loss         | 0.00016  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3500      |
# |    time_elapsed       | 2604      |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -2.41     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 3499      |
# |    policy_loss        | -0.000958 |
# |    std                | 2.71      |
# |    value_loss         | 4e-07     |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 3600     |
# |    time_elapsed       | 2679     |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -2.46    |
# |    explained_variance | -0.041   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.011   |
# |    std                | 2.84     |
# |    value_loss         | 1.81e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 3700     |
# |    time_elapsed       | 2753     |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -2.51    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.000656 |
# |    std                | 2.98     |
# |    value_loss         | 2.23e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 3800     |
# |    time_elapsed       | 2827     |
# |    total_timesteps    | 19000    |
# | train/                |          |
# |    entropy_loss       | -2.55    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3799     |
# |    policy_loss        | 3.86e-05 |
# |    std                | 3.11     |
# |    value_loss         | 3.21e-10 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 3900      |
# |    time_elapsed       | 2902      |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -2.59     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 3899      |
# |    policy_loss        | 5.99e-06  |
# |    std                | 3.23      |
# |    value_loss         | 6.74e-12  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 4000     |
# |    time_elapsed       | 2976     |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -2.64    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 3999     |
# |    policy_loss        | 1.82e-06 |
# |    std                | 3.38     |
# |    value_loss         | 6.39e-13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 4100     |
# |    time_elapsed       | 3051     |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -2.66    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.00112 |
# |    std                | 3.46     |
# |    value_loss         | 2.1e-07  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 4200      |
# |    time_elapsed       | 3125      |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -2.69     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 4199      |
# |    policy_loss        | -9.29e-08 |
# |    std                | 3.57      |
# |    value_loss         | 2.8e-16   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 4300     |
# |    time_elapsed       | 3200     |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -2.73    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.000151 |
# |    std                | 3.71     |
# |    value_loss         | 4.3e-09  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 4400     |
# |    time_elapsed       | 3273     |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -2.77    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.000931 |
# |    std                | 3.88     |
# |    value_loss         | 1.07e-07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 4500      |
# |    time_elapsed       | 3347      |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -2.82     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 4499      |
# |    policy_loss        | 5.84e-05  |
# |    std                | 4.05      |
# |    value_loss         | 2.43e-09  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 4600     |
# |    time_elapsed       | 3420     |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -2.86    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.000351 |
# |    std                | 4.25     |
# |    value_loss         | 3.15e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 4700     |
# |    time_elapsed       | 3494     |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.00351  |
# |    std                | 4.46     |
# |    value_loss         | 1.77e-06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 4800      |
# |    time_elapsed       | 3567      |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -2.96     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 4799      |
# |    policy_loss        | -0.000102 |
# |    std                | 4.68      |
# |    value_loss         | 2.09e-09  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 4900     |
# |    time_elapsed       | 3642     |
# |    total_timesteps    | 24500    |
# | train/                |          |
# |    entropy_loss       | -3.01    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.00789  |
# |    std                | 4.93     |
# |    value_loss         | 6.81e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5000     |
# |    time_elapsed       | 3716     |
# |    total_timesteps    | 25000    |
# | train/                |          |
# |    entropy_loss       | -3.04    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.000245 |
# |    std                | 5.09     |
# |    value_loss         | 1.03e-08 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5100     |
# |    time_elapsed       | 3790     |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -3.08    |
# |    explained_variance | -2.67    |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5099     |
# |    policy_loss        | -0.00274 |
# |    std                | 5.29     |
# |    value_loss         | 7.5e-07  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5200     |
# |    time_elapsed       | 3865     |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -3.13    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.00127  |
# |    std                | 5.54     |
# |    value_loss         | 1.98e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5300     |
# |    time_elapsed       | 3939     |
# |    total_timesteps    | 26500    |
# | train/                |          |
# |    entropy_loss       | -3.18    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.000215 |
# |    std                | 5.81     |
# |    value_loss         | 6.89e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 5400      |
# |    time_elapsed       | 4014      |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -3.23     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 5399      |
# |    policy_loss        | -0.000174 |
# |    std                | 6.1       |
# |    value_loss         | 4.2e-09   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5500     |
# |    time_elapsed       | 4088     |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -3.28    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.0015  |
# |    std                | 6.42     |
# |    value_loss         | 2.61e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5600     |
# |    time_elapsed       | 4163     |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -3.32    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.000235 |
# |    std                | 6.71     |
# |    value_loss         | 6.75e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 5700      |
# |    time_elapsed       | 4237      |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -3.37     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 5699      |
# |    policy_loss        | -0.000361 |
# |    std                | 7.04      |
# |    value_loss         | 1.56e-08  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 5800     |
# |    time_elapsed       | 4312     |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -3.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.000172 |
# |    std                | 7.39     |
# |    value_loss         | 4.18e-09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 5900      |
# |    time_elapsed       | 4386      |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -3.47     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 5899      |
# |    policy_loss        | -3.73e-05 |
# |    std                | 7.76      |
# |    value_loss         | 3.23e-10  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 6000     |
# |    time_elapsed       | 4460     |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -3.52    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 5999     |
# |    policy_loss        | 5.46e-05 |
# |    std                | 8.16     |
# |    value_loss         | 4.66e-10 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 6100      |
# |    time_elapsed       | 4535      |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -3.56     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 6099      |
# |    policy_loss        | -0.00022  |
# |    std                | 8.49      |
# |    value_loss         | 4.55e-09  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 6200     |
# |    time_elapsed       | 4609     |
# |    total_timesteps    | 31000    |
# | train/                |          |
# |    entropy_loss       | -3.6     |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6199     |
# |    policy_loss        | 1.8e-06  |
# |    std                | 8.84     |
# |    value_loss         | 1.17e-12 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 6300     |
# |    time_elapsed       | 4684     |
# |    total_timesteps    | 31500    |
# | train/                |          |
# |    entropy_loss       | -3.64    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6299     |
# |    policy_loss        | 4.08e-06 |
# |    std                | 9.23     |
# |    value_loss         | 1.38e-12 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 6400      |
# |    time_elapsed       | 4759      |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -3.69     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 6399      |
# |    policy_loss        | -2.14e-06 |
# |    std                | 9.69      |
# |    value_loss         | 4.94e-13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 6500      |
# |    time_elapsed       | 4833      |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -3.74     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 6499      |
# |    policy_loss        | -1.02e-06 |
# |    std                | 10.2      |
# |    value_loss         | 1.11e-13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 6600      |
# |    time_elapsed       | 4907      |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -3.79     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 6599      |
# |    policy_loss        | -8.35e-07 |
# |    std                | 10.7      |
# |    value_loss         | 6.34e-14  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 6700      |
# |    time_elapsed       | 4982      |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -3.84     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 6699      |
# |    policy_loss        | -3.44e-07 |
# |    std                | 11.2      |
# |    value_loss         | 9.14e-15  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 6800     |
# |    time_elapsed       | 5056     |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -3.89    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.0235   |
# |    std                | 11.8     |
# |    value_loss         | 5.09e-05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 6900     |
# |    time_elapsed       | 5130     |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -3.94    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 6899     |
# |    policy_loss        | 2.42e-07 |
# |    std                | 12.4     |
# |    value_loss         | 1.22e-14 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 7000      |
# |    time_elapsed       | 5205      |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -3.98     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 6999      |
# |    policy_loss        | -3.25e-08 |
# |    std                | 13        |
# |    value_loss         | 6.14e-17  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 7100      |
# |    time_elapsed       | 5279      |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -4.03     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 7099      |
# |    policy_loss        | -3.33e-08 |
# |    std                | 13.6      |
# |    value_loss         | 1.31e-16  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 7200      |
# |    time_elapsed       | 5354      |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -4.08     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 7199      |
# |    policy_loss        | -5.06e-08 |
# |    std                | 14.3      |
# |    value_loss         | 4.29e-17  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 7300      |
# |    time_elapsed       | 5428      |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -4.13     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 7299      |
# |    policy_loss        | -6.91e-10 |
# |    std                | 15        |
# |    value_loss         | 7.89e-20  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 7400     |
# |    time_elapsed       | 5503     |
# |    total_timesteps    | 37000    |
# | train/                |          |
# |    entropy_loss       | -4.18    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7399     |
# |    policy_loss        | 3.75e-08 |
# |    std                | 15.8     |
# |    value_loss         | 2.06e-16 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 7500      |
# |    time_elapsed       | 5577      |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -4.22     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 7499      |
# |    policy_loss        | -0.00775  |
# |    std                | 16.5      |
# |    value_loss         | 3.72e-06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 7600      |
# |    time_elapsed       | 5652      |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -4.27     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 7599      |
# |    policy_loss        | 3.44e-08  |
# |    std                | 17.4      |
# |    value_loss         | 5.63e-17  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 7700     |
# |    time_elapsed       | 5726     |
# |    total_timesteps    | 38500    |
# | train/                |          |
# |    entropy_loss       | -4.32    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7699     |
# |    policy_loss        | 6.26e-08 |
# |    std                | 18.3     |
# |    value_loss         | 4.59e-17 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 7800     |
# |    time_elapsed       | 5801     |
# |    total_timesteps    | 39000    |
# | train/                |          |
# |    entropy_loss       | -4.38    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7799     |
# |    policy_loss        | 0.00349  |
# |    std                | 19.2     |
# |    value_loss         | 8.46e-07 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 7900     |
# |    time_elapsed       | 5875     |
# |    total_timesteps    | 39500    |
# | train/                |          |
# |    entropy_loss       | -4.42    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7899     |
# |    policy_loss        | 1.17e-07 |
# |    std                | 20.1     |
# |    value_loss         | 1.68e-16 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 8000     |
# |    time_elapsed       | 5949     |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -4.47    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 7999     |
# |    policy_loss        | 7.55e-08 |
# |    std                | 21.1     |
# |    value_loss         | 1.78e-15 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 8100     |
# |    time_elapsed       | 6024     |
# |    total_timesteps    | 40500    |
# | train/                |          |
# |    entropy_loss       | -4.51    |
# |    explained_variance | 0.0787   |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 8099     |
# |    policy_loss        | 0.0109   |
# |    std                | 22       |
# |    value_loss         | 6.75e-06 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 8200     |
# |    time_elapsed       | 6098     |
# |    total_timesteps    | 41000    |
# | train/                |          |
# |    entropy_loss       | -4.55    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 8199     |
# |    policy_loss        | 1.74e-05 |
# |    std                | 22.9     |
# |    value_loss         | 1.56e-11 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 8300      |
# |    time_elapsed       | 6173      |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -4.59     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 8299      |
# |    policy_loss        | -1.89e-05 |
# |    std                | 23.9      |
# |    value_loss         | 1.43e-11  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 6        |
# |    iterations         | 8400     |
# |    time_elapsed       | 6247     |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -4.64    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0005   |
# |    n_updates          | 8399     |
# |    policy_loss        | 1.88e-06 |
# |    std                | 25       |
# |    value_loss         | 2.37e-13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# |    iterations         | 8500      |
# |    time_elapsed       | 6321      |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -4.69     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0005    |
# |    n_updates          | 8499      |
# |    policy_loss        | -6.13e-08 |
# |    std                | 26.2      |
# |    value_loss         | 1.59e-15  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 6         |
# ...
# |    policy_gradient_loss | -0.000632    |
# |    std                  | 1.08         |
# |    value_loss           | 1.39e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 31           |
# |    time_elapsed         | 9361         |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0003716307 |
# |    clip_fraction        | 0.0329       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.096        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0317      |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00124     |
# |    std                  | 1.07         |
# |    value_loss           | 1.19e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 32           |
# |    time_elapsed         | 9663         |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0033147796 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0289      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0034      |
# |    std                  | 1.07         |
# |    value_loss           | 3.68e-08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 33           |
# |    time_elapsed         | 9965         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0022133284 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.49        |
# |    explained_variance   | -27          |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0118      |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.000643    |
# |    std                  | 1.08         |
# |    value_loss           | 8.59e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 34           |
# |    time_elapsed         | 10266        |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0008822103 |
# |    clip_fraction        | 0.00264      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.846        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0128      |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.000782    |
# |    std                  | 1.09         |
# |    value_loss           | 1.61e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 35           |
# |    time_elapsed         | 10568        |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0053103575 |
# |    clip_fraction        | 0.016        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | -5.21        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00928     |
# |    n_updates            | 340          |
# |    policy_gradient_loss | 0.000314     |
# |    std                  | 1.09         |
# |    value_loss           | 1.22e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 36          |
# |    time_elapsed         | 10870       |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005000259 |
# |    clip_fraction        | 0.0151      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0159     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00192    |
# |    std                  | 1.11        |
# |    value_loss           | 9.37e-08    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 37           |
# |    time_elapsed         | 11171        |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0025181076 |
# |    clip_fraction        | 0.00952      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | 0.551        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0124      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -7.68e-05    |
# |    std                  | 1.12         |
# |    value_loss           | 1.2e-07      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 38           |
# |    time_elapsed         | 11473        |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0059077227 |
# |    clip_fraction        | 0.0595       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | -36          |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0244      |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00147     |
# |    std                  | 1.1          |
# |    value_loss           | 4.97e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 39           |
# |    time_elapsed         | 11775        |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0067668096 |
# |    clip_fraction        | 0.0398       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | -3.36        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0169      |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.000624    |
# |    std                  | 1.11         |
# |    value_loss           | 6.48e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 40           |
# |    time_elapsed         | 12076        |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0056134323 |
# |    clip_fraction        | 0.0678       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.53        |
# |    explained_variance   | -7.63        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00578     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00129     |
# |    std                  | 1.11         |
# |    value_loss           | 3.42e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 41           |
# |    time_elapsed         | 12378        |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0041407524 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.52        |
# |    explained_variance   | 0.917        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0156      |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00339     |
# |    std                  | 1.11         |
# |    value_loss           | 2.37e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 42          |
# |    time_elapsed         | 12680       |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.003081485 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | -0.251      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00043     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00255    |
# |    std                  | 1.1         |
# |    value_loss           | 1.96e-08    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 43           |
# |    time_elapsed         | 12982        |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0008356218 |
# |    clip_fraction        | 0.0043       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | -2.51        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0229      |
# |    n_updates            | 420          |
# |    policy_gradient_loss | 4.29e-05     |
# |    std                  | 1.09         |
# |    value_loss           | 5.8e-06      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 44           |
# |    time_elapsed         | 13284        |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0069237193 |
# |    clip_fraction        | 0.0389       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | -0.622       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0235      |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00169     |
# |    std                  | 1.1          |
# |    value_loss           | 0.000187     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 45           |
# |    time_elapsed         | 13586        |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0057014367 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.51        |
# |    explained_variance   | -2.21        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0262      |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00142     |
# |    std                  | 1.09         |
# |    value_loss           | 0.000192     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 6           |
# |    iterations           | 46          |
# |    time_elapsed         | 13887       |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004768331 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -0.132      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0174     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.000563   |
# |    std                  | 1.09        |
# |    value_loss           | 1.08e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 47           |
# |    time_elapsed         | 14188        |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0009939144 |
# |    clip_fraction        | 0.0218       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0178      |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00165     |
# |    std                  | 1.08         |
# |    value_loss           | 1.59e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 48           |
# |    time_elapsed         | 14491        |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0026411475 |
# |    clip_fraction        | 0.014        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0275      |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00115     |
# |    std                  | 1.09         |
# |    value_loss           | 1.09e-07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 6            |
# |    iterations           | 49           |
# |    time_elapsed         | 14793        |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0011726172 |
# |    clip_fraction        | 0.0041       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.5         |
# |    explained_variance   | 0.856        |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.0216      |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 4.79e-05     |
# |    std                  | 1.08         |
# |    value_loss           | 2.72e-06     |
# ------------------------------------------
# ======PPO Validation from:  2020-10-27T17:01:00+07:00 to  2020-10-27T18:04:00+07:00
# PPO Sharpe Ratio:  -0.8868598757533459
# ======DDPG Training========
# {'action_noise': OrnsteinUhlenbeckActionNoise(mu=[0.], sigma=[0.1]), 'buffer_size': 50000, 'learning_rate': 5e-06, 'batch_size': 128}
# Using cuda device
# Logging to tensorboard_log/ddpg\ddpg_126_2

# %%
df_summary

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %%
unique_trade_date = processed_full[(processed_full.date > val_test_start)&(processed_full.date <= val_test_end)].date.unique()

# %%
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))

# %%
df_account_value.head()

# %%
# %matplotlib inline
df_account_value.account_value.plot()

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to IHSG===========")
# %matplotlib inline
backtest_plot(df_account_value, 
             baseline_ticker = '^JKSE', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])

# %% [markdown]
# <a id='6.3'></a>
# ## 7.3 Baseline Stats

# %%
print("==============Get Baseline Stats===========")
baseline_perf_stats=get_baseline('^JKSE',
                                  start = df_account_value.loc[0,'date'],
                                  end = df_account_value.loc[len(df_account_value)-1,'date'])

# %% [markdown]
# ####
