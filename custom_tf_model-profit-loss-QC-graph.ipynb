# %%
import matplotlib.pyplot as plt

import numpy as np 
import pandas as pd

# %%
window_size = 12*60

# %%
train = pd.read_csv('train_timeframes3.csv').iloc[window_size-1:]
test = pd.read_csv('test_timeframes3.csv').iloc[window_size-1:]

# %%
train = train.reset_index(drop=True)
test = test.reset_index(drop=True)

# %%
input_train = np.load('inputs_train/' + str(0) + '.npy')

# %%
input_train = input_train[:,1:]

# %%
input_train*255
# Out:
# array([[ 55.16928159,  65.69777044,  54.95871181,  65.06606111],
#        [ 65.48720066,  68.22460776,  61.27580512,  61.27580512],
#        [ 61.4863749 ,  63.80264244,  61.4863749 ,  63.38150289],
#        ...,
#        [192.46077622, 199.19900908, 192.46077622, 197.93559042],
#        [197.51445087, 201.09413708, 194.56647399, 196.88274154],
#        [196.2510322 , 198.56729975, 194.35590421, 194.56647399]])

# %%
input_train.shape
# Out:
# (720, 4)

# %%
import plotly.graph_objects as go

# %%
for i in range(10):
    input_train = np.load('inputs_train/' + str(i) + '.npy')
    fig = go.Figure(data=go.Candlestick(x=list(range(input_train.shape[0])),
                    open=input_train[:,0],
                    high=input_train[:,1],
                    low=input_train[:,2],
                    close=input_train[:,3]))
    fig.show()
# Out:
# <div>
#
#
#             <div id="96f6ca32-8ce8-4c1a-8dc4-38c9bb1dd205" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("96f6ca32-8ce8-4c1a-8dc4-38c9bb1dd205")) {
#                     Plotly.newPlot(
#                         '96f6ca32-8ce8-4c1a-8dc4-38c9bb1dd205',
# ...

# %%
go.Figure?

# %%
go.Ohlc?
