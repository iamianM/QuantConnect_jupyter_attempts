# %%
from os import listdir, walk
from os.path import isfile, join
import pandas as pd
import datetime

# %%
path = "C:/Users/Mcian/Downloads/crypto_data/"

# %%
coins = ['1INCH',
'AAVE',
'ADA',
'ALGO',
'ANKR',
'ATOM',
'BAL',
'BAND',
'BAT',
'BCH',
'BNT',
'BTC',
'CGLD',
'COMP',
'CRV',
'CTSI',
'DAI',
'DASH',
'DOGE',
'ENJ',
'EOS',
'ETC',
'ETH',
'FIL',
'FORTH',
'GRT',
'ICP',
'KNC',
'LINK',
'LRC',
'LTC',
'MANA',
'MIR',
'MKR',
'NKN',
'NMR',
'NU',
'OGN',
'OMG',
'OXT',
'REN',
'REP',
'RLC',
'SOL',
'SNX',
'STORJ',
'TRB',
'UMA',
'UNI',
'XLM',
'XTZ',
'YFI',
'ZEC',
'ZRX']

# %%
files = []
for coin in coins:
    files.extend([f for f in listdir(path) if coin.lower() in f and f not in badfiles])

# %%
','.join([f.split('.')[0] for f in files if f not in badfiles])
# Out:
# '1inchusd,1inchust,aaveusd,aaveust,adabtc,adaf0ustf0,adausd,adaust,balust,bandusd,bandust,batbtc,bateth,batusd,bchabcusd,bchnusd,bntusd,adabtc,algbtc,ampbtc,antbtc,atobtc,batbtc,bsvbtc,btccnht,btcdomf0ustf0,btceur,btcf0ustf0,btcgbp,btcjpy,btcusd,btcust,btcxch,btgbtc,datbtc,dogbtc,dotbtc,dotf0btcf0,dshbtc,duskbtc,edobtc,eosbtc,etcbtc,ethbtc,ethf0btcf0,exrdbtc,gntbtc,idxbtc,iotbtc,jstbtc,kncbtc,leobtc,lrcbtc,ltcbtc,ltcf0btcf0,mkrbtc,mnabtc,neobtc,omgbtc,omnbtc,qtmbtc,repbtc,sanbtc,testbtcf0testusdtf0,testbtctestusd,testbtctestusdt,trxbtc,uosbtc,vsybtc,xautbtc,xautf0btcf0,xlmbtc,xmrbtc,xrpbtc,xtzbtc,zecbtc,zilbtc,zrxbtc,compusd,compust,daieth,daiusd,dogef0ustf0,dogeusd,dogeust,enjusd,eosbtc,eosdtusd,eosdtust,eoseth,eoseur,eosf0ustf0,eosgbp,eosjpy,eosusd,eosust,leoeos,etcbtc,etcusd,anteth,atoeth,bateth,daieth,edoeth,eoseth,eth2xeth,eth2xusd,eth2xust,ethbtc,etheur,ethf0btcf0,ethf0ustf0,ethgbp,ethjpy,ethusd,ethust,etpeth,gnteth,ioteth,leoeth,mkreth,neceth,neoeth,omgeth,pnketh,saneth,trxeth,wbteth,xcheth,xlmeth,zrxeth,filusd,filust,forthusd,forthust,kncbtc,kncusd,linkf0ustf0,linkusd,linkust,lrcbtc,lrcusd,ltcbtc,ltcf0btcf0,ltcf0ustf0,ltcusd,ltcust,mkrbtc,mkreth,mkrusd,bchnusd,bosonusd,bosonust,drnusd,funusd,genusd,kanusd,kanust,manusd,mlnusd,mtnusd,nutusd,nutust,oceanusd,oceanust,omnusd,rcnusd,sanusd,sunusd,sunust,tknusd,xsnusd,zcnusd,omgbtc,omgeth,omgusd,repbtc,repusd,solusd,solust,snxusd,snxust,unif0ustf0,uniusd,uniust,xlmbtc,xlmeth,xlmf0ustf0,xlmusd,xlmust,xtzbtc,xtzusd,yfiusd,yfiust,zecbtc,zecusd,zrxbtc,zrxeth,zrxusd'

# %%
import datetime
def convert_to_time(t):
    t /= 1000
    seconds = int(t%60)
    t /= 60
    minutes = int(t%60)
    t /= 60
    hours = int(t%24)
    return datetime.time(hours, minutes, seconds)

# %%
len(files)
# Out:
# 199

# %%
files[5]
# Out:
# 'adaf0ustf0.csv'

# %%
badfiles = ['balusd.csv', 'daibtc.csv', 'etpbtc.csv', 'vetbtc.csv', 'rbtbtc.csv', 'eusbtc.csv', 'qtfbtc.csv']

# %%
import matplotlib.pyplot as plt
for f in files:
    temp = pd.read_csv(path+f)
    temp['time'] = temp['time'].apply(lambda x: datetime.date.fromtimestamp(x/1000))
    if temp.shape[0] > 0:
        print(f)
        plt.plot(temp['time'], temp['close'])
        plt.xticks(rotation = 45)
        plt.title(f)
        plt.show()
# Out:
# adabtc.csv
# adausd.csv
# adaust.csv
# balusd.csv
# balust.csv
# batbtc.csv
# bateth.csv
# batusd.csv
# bntusd.csv
# adabtc.csv
# algbtc.csv
# ampbtc.csv
# antbtc.csv
# atobtc.csv
# batbtc.csv
# bsvbtc.csv
# btceur.csv
# btcgbp.csv
# btcjpy.csv
# btcusd.csv
# btcust.csv
# btcxch.csv
# btgbtc.csv
# daibtc.csv
# datbtc.csv
# dogbtc.csv
# dotbtc.csv
# dshbtc.csv
# edobtc.csv
# eosbtc.csv
# etcbtc.csv
# ethbtc.csv
# etpbtc.csv
# eusbtc.csv
# gntbtc.csv
# iotbtc.csv
# jstbtc.csv
# kncbtc.csv
# leobtc.csv
# lrcbtc.csv
# ltcbtc.csv
# mkrbtc.csv
# mnabtc.csv
# neobtc.csv
# omgbtc.csv
# omnbtc.csv
# qtfbtc.csv
# qtmbtc.csv
# rbtbtc.csv
# repbtc.csv
# sanbtc.csv
# trxbtc.csv
# uosbtc.csv
# vetbtc.csv
# vsybtc.csv
# xlmbtc.csv
# xmrbtc.csv
# xrpbtc.csv
# xtzbtc.csv
# zecbtc.csv
# zilbtc.csv
# zrxbtc.csv
# daibtc.csv
# daieth.csv
# daiusd.csv
# enjusd.csv
# eosbtc.csv
# eoseth.csv
# eoseur.csv
# eosgbp.csv
# eosjpy.csv
# eosusd.csv
# eosust.csv
# leoeos.csv
# etcbtc.csv
# etcusd.csv
# anteth.csv
# atoeth.csv
# bateth.csv
# daieth.csv
# edoeth.csv
# eoseth.csv
# ethbtc.csv
# etheur.csv
# ethgbp.csv
# ethjpy.csv
# ethusd.csv
# ethust.csv
# etpeth.csv
# gnteth.csv
# ioteth.csv
# leoeth.csv
# mkreth.csv
# neceth.csv
# neoeth.csv
# omgeth.csv
# pnketh.csv
# saneth.csv
# trxeth.csv
# wbteth.csv
# xcheth.csv
# xlmeth.csv
# zrxeth.csv
# filusd.csv
# filust.csv
# kncbtc.csv
# kncusd.csv
# lrcbtc.csv
# lrcusd.csv
# ltcbtc.csv
# ltcusd.csv
# ltcust.csv
# mkrbtc.csv
# mkreth.csv
# mkrusd.csv
# drnusd.csv
# funusd.csv
# genusd.csv
# kanusd.csv
# kanust.csv
# manusd.csv
# mlnusd.csv
# mtnusd.csv
# nutusd.csv
# nutust.csv
# omnusd.csv
# rcnusd.csv
# sanusd.csv
# sunusd.csv
# sunust.csv
# tknusd.csv
# xsnusd.csv
# zcnusd.csv
# omgbtc.csv
# omgeth.csv
# omgusd.csv
# repbtc.csv
# repusd.csv
# solusd.csv
# solust.csv
# snxusd.csv
# snxust.csv
# uniusd.csv
# uniust.csv
# xlmbtc.csv
# xlmeth.csv
# xlmusd.csv
# xlmust.csv
# xtzbtc.csv
# xtzusd.csv
# yfiusd.csv
# yfiust.csv
# zecbtc.csv
# zecusd.csv
# zrxbtc.csv
# zrxeth.csv
# zrxusd.csv

# %%
        plt.plot(temp['time'], temp['close'])
        plt.xticks(rotation = 45)
        plt.title(f)
# Out:
# Text(0.5, 1.0, 'zrxusd.csv')

# %%
temp
# Out:
# Empty DataFrame
# Columns: [time, open, close, high, low, volume, datetime]
# Index: []

# %%
import talib

INDICATORS = {
    'BBANDS': {'method': 'BBANDS', 'period': 20}, 'SMA_SLOW': {'method': 'SMA', 'period': 200},
    'SMA_FAST': {'method': 'SMA', 'period': 50}, 'EMA_SLOW': {'method': 'EMA', 'period': 20},
    'EMA_FAST': {'method': 'EMA', 'period': 9}, 'ATR': {'method': 'ATR', 'period': 14},
    'RSI': {'method': 'RSI', 'period': 14}
}

def get_indicators(df):
    df = df.copy()
    opens = df['open'].values
    highs = df['high'].values
    lows = df['low'].values
    closes = df['close'].values
    # Add indicator columns to DataFrame
    for indicator_name, indicator_values in INDICATORS.items():
        if indicator_name == 'BBANDS':
            ub, _, lb = getattr(talib, indicator_values['method'])(closes, indicator_values['period'])
            df[f'{indicator_name}_UB'], df[f'{indicator_name}_LB'] = ub, lb
        elif indicator_name == 'ATR':
            df[indicator_name] = \
                getattr(talib, indicator_values['method'])(highs,
                                                           lows,
                                                           closes,
                                                           indicator_values['period'])
        else:
            df[indicator_name] = getattr(talib, indicator_values['method'])(closes,
                                                                             indicator_values['period'])
    return df

# %%
train = pd.DataFrame()
test = pd.DataFrame()
for i, f in enumerate(files):
    if (i+1) % 10 == 0:
        print(i)
    temp = pd.read_csv(path+f)
    if 'Unnamed: 0' in temp.columns:
        del temp['Unnamed: 0']
    temp.dropna(inplace=True)
    if temp.shape[0] < 10000:
        continue
    temp = temp.iloc[1000:-1000]
    temp['datetime'] = temp['time'].apply(lambda x: datetime.date.fromtimestamp(x/1000))
    temp['time'] = temp['time'].apply(convert_to_time)
    temp = get_indicators(temp)
    temp.dropna(inplace=True)
    
    symbol = f.split('.')[0]
    temp['symbol'] = symbol
#     test = pd.concat([test, temp[[t.year == 2021 for t in temp['datetime']]]])
    train = pd.concat([train, temp[[t.year != 2021 for t in temp['datetime']]]])
# Out:
# 9
# 19
# 29
# 39
# 49
# 59
# 69
# 79
# 89
# 99
# 109
# 119
# 129
# 139
# 149
# 159
# 169
# 179
# 189

# %%
train = train[~train['symbol'].isin(['sunust', 'sunusd', 'zcnusd', 'omnusd'])]

# %%
train['symbol'].value_counts()
# Out:
# btcusd    3146060
# ethbtc    2933230
# ltcbtc    2295146
# ethusd    1932779
# ltcusd    1817409
#            ...
# sunusd       3168
# omnbtc        670
# zcnusd        628
# omnusd        416
# leoeos         34
# Name: symbol, Length: 111, dtype: int64

# %%
f = 'btcusd.csv'
temp = pd.read_csv(path+f)
if 'Unnamed: 0' in temp.columns:
    del temp['Unnamed: 0']
temp.dropna(inplace=True)
temp['datetime'] = temp['time'].apply(lambda x: datetime.date.fromtimestamp(x/1000))
temp['time'] = temp['time'].apply(convert_to_time)
temp = get_indicators(temp)
temp.dropna(inplace=True)

symbol = f.split('.')[0]
temp['symbol'] = symbol
test = temp[[t.year == 2021 for t in temp['datetime']]]

# %%
train.set_index('datetime', inplace=True)
test.set_index('datetime', inplace=True)

# %%
len(train), len(test)
# Out:
# (35779682, 213354)

# %%
train
# Out:
#             time     open    close     high      low        volume  \
# 1199    15:11:00  0.00001  0.00001  0.00001  0.00001      3.928189
# 1200    15:28:00  0.00001  0.00001  0.00001  0.00001      3.421000
# 1201    15:31:00  0.00001  0.00001  0.00001  0.00001      1.663845
# 1202    15:37:00  0.00001  0.00001  0.00001  0.00001      0.009000
# 1203    15:42:00  0.00001  0.00001  0.00001  0.00001      0.354525
# ...          ...      ...      ...      ...      ...           ...
# 263604  07:42:00  0.35492  0.35492  0.35492  0.35492      7.336480
# 263605  07:45:00  0.35581  0.35643  0.35643  0.35581  29304.546669
# 263606  07:46:00  0.35641  0.35676  0.35703  0.35641  21771.953556
# 263607  07:47:00  0.35664  0.35699  0.35699  0.35664  19648.000931
# 263608  07:56:00  0.35515  0.35515  0.35515  0.35515      7.726662
#
#           datetime  BBANDS_UB  BBANDS_LB  SMA_SLOW  SMA_FAST  EMA_SLOW  \
# 1199    2020-08-30   0.000010   0.000010  0.000010  0.000010  0.000010
# 1200    2020-08-30   0.000010   0.000010  0.000010  0.000010  0.000010
# 1201    2020-08-30   0.000010   0.000010  0.000010  0.000010  0.000010
# 1202    2020-08-30   0.000010   0.000010  0.000010  0.000010  0.000010
# 1203    2020-08-30   0.000010   0.000010  0.000010  0.000010  0.000010
# ...            ...        ...        ...       ...       ...       ...
# 263604  2020-12-31   0.360946   0.353686  0.355176  0.358896  0.356959
# 263605  2020-12-31   0.360595   0.353693  0.355196  0.358818  0.356909
# 263606  2020-12-31   0.360383   0.353684  0.355212  0.358748  0.356895
# 263607  2020-12-31   0.360165   0.353704  0.355226  0.358714  0.356904
# 263608  2020-12-31   0.360097   0.353508  0.355231  0.358611  0.356737
#
#         EMA_FAST           ATR        RSI  symbol
# 1199    0.000010  2.702133e-08  43.024676  adabtc
# 1200    0.000010  2.651981e-08  46.093827  adabtc
# 1201    0.000010  2.462554e-08  46.093827  adabtc
# 1202    0.000010  2.286657e-08  46.093827  adabtc
# 1203    0.000010  2.194753e-08  44.593697  adabtc
# ...          ...           ...        ...     ...
# 263604  0.355922  1.094217e-03  40.102117  zrxusd
# 263605  0.356024  1.123916e-03  46.619407  zrxusd
# 263606  0.356171  1.087922e-03  47.952251  zrxusd
# 263607  0.356335  1.035213e-03  48.909737  zrxusd
# 263608  0.356098  1.092698e-03  42.218478  zrxusd
#
# [35779682 rows x 16 columns]

# %%
def cumsample(x):
    if x.shape[0] == 0:
        return pd.DataFrame()
    else:
        return pd.DataFrame({'open': [x['open_1min'].iloc[0]]*len(x), 'close': x['close_1min'], 'close_bid': x['close_bid_1min'], 'high': x['close_1min'].cummax(), 'low': x['close_1min'].cummin()})

# %%
train.to_csv('train_crypt.csv', index=False)
test.to_csv('test_crypt.csv', index=False)

# %%
# %%time
timeframes = ['5min', '15min', '30min', '60min']
dfs = pd.DataFrame()
for frame in timeframes:
    print(frame)
    df = train.resample(frame).apply(cumsample)
    df.index = df.index.droplevel()
    df.columns = [c+'_'+frame for c in df.columns]
    dfs = pd.concat([dfs, df], axis=1)
train = pd.concat([train, dfs], axis=1)
# Out:
# 5min
# 15min
# 30min
# 60min
# Wall time: 39min 54s

# %%
# %%time
timeframes = ['5min', '15min', '30min', '60min']
dfs = pd.DataFrame()
for frame in timeframes:
    print(frame)
    df = test.resample(frame).apply(cumsample)
    df.index = df.index.droplevel()
    df.columns = [c+'_'+frame for c in df.columns]
    dfs = pd.concat([dfs, df], axis=1)
test = pd.concat([test, dfs], axis=1)
# Out:
# 5min
# 15min
# 30min
# 60min
# Wall time: 41.3 s

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 317435 entries, 2016-01-04 12:01:00+00:00 to 2020-12-30 19:59:00+00:00
# Data columns (total 28 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   time             317435 non-null  object
#  1   date             317435 non-null  object
#  2   spread           317435 non-null  float64
#  3   close_bid_1min   317435 non-null  float64
#  4   open_1min        317435 non-null  float64
#  5   high_1min        317435 non-null  float64
#  6   low_1min         317435 non-null  float64
#  7   close_1min       317435 non-null  float64
#  8   open_5min        317435 non-null  float64
#  9   close_5min       317435 non-null  float64
#  10  close_bid_5min   317435 non-null  float64
#  11  high_5min        317435 non-null  float64
#  12  low_5min         317435 non-null  float64
#  13  open_15min       317435 non-null  float64
#  14  close_15min      317435 non-null  float64
#  15  close_bid_15min  317435 non-null  float64
#  16  high_15min       317435 non-null  float64
#  17  low_15min        317435 non-null  float64
#  18  open_30min       317435 non-null  float64
#  19  close_30min      317435 non-null  float64
#  20  close_bid_30min  317435 non-null  float64
#  21  high_30min       317435 non-null  float64
#  22  low_30min        317435 non-null  float64
#  23  open_60min       317435 non-null  float64
#  24  close_60min      317435 non-null  float64
#  25  close_bid_60min  317435 non-null  float64
#  26  high_60min       317435 non-null  float64
#  27  low_60min        317435 non-null  float64
# dtypes: float64(26), object(2)
# memory usage: 70.2+ MB

# %%
train.mean()
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py", line 3427, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-71-b2f34c448aca>", line 1, in <module>
#     train.mean()
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py", line 11113, in mean
#     return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py", line 10722, in mean
#     "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py", line 10707, in _stat_function
#     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py", line 8847, in _reduce
#     res, indexer = df._mgr.reduce(blk_func, ignore_failures=ignore_failures)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py", line 354, in reduce
#     nbs = blk.reduce(func, ignore_failures)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py", line 2533, in reduce
#     None, mask_func, False, ignore_failures=ignore_failures
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py", line 533, in split_and_operate
#     nv = f(m, v, i)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py", line 2530, in mask_func
#     return func(values)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py", line 8819, in blk_func
#     return op(values, axis=1, skipna=skipna, **kwds)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\nanops.py", line 71, in _f
#     return f(*args, **kwargs)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\nanops.py", line 133, in f
#     result = alt(values, axis=axis, skipna=skipna, **kwds)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\nanops.py", line 392, in new_func
#     result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\nanops.py", line 631, in nanmean
#     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py", line 2054, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py", line 244, in wrapped
#     def wrapped(*args, **kwargs):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-71-b2f34c448aca> in <module>
# ----> 1 train.mean()
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11112         def mean(self, axis=None, skipna=None, level=None, numeric_only=None, **kwargs):
# > 11113             return NDFrame.mean(self, axis, skipna, level, numeric_only, **kwargs)
#   11114
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in mean(self, axis, skipna, level, numeric_only, **kwargs)
#   10721         return self._stat_function(
# > 10722             "mean", nanops.nanmean, axis, skipna, level, numeric_only, **kwargs
#   10723         )
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\generic.py in _stat_function(self, name, func, axis, skipna, level, numeric_only, **kwargs)
#   10706         return self._reduce(
# > 10707             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   10708         )
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    8846             #  simple case where we can use BlockManager.reduce
# -> 8847             res, indexer = df._mgr.reduce(blk_func, ignore_failures=ignore_failures)
#    8848             out = df._constructor(res).iloc[0]
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in reduce(self, func, ignore_failures)
#     353         for blk in self.blocks:
# --> 354             nbs = blk.reduce(func, ignore_failures)
#     355             res_blocks.extend(nbs)
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py in reduce(self, func, ignore_failures)
#    2532             return self.split_and_operate(
# -> 2533                 None, mask_func, False, ignore_failures=ignore_failures
#    2534             )
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py in split_and_operate(self, mask, f, inplace, ignore_failures)
#     532                 try:
# --> 533                     nv = f(m, v, i)
#     534                 except TypeError:
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\blocks.py in mask_func(mask, values, inplace)
#    2529                     values = values.reshape(1, -1)
# -> 2530                 return func(values)
#    2531
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in blk_func(values)
#    8818             else:
# -> 8819                 return op(values, axis=1, skipna=skipna, **kwds)
#    8820
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\nanops.py in f(values, axis, skipna, **kwds)
#     132             else:
# --> 133                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     134
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     391
# --> 392         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     393
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\pandas\core\nanops.py in nanmean(values, axis, skipna, mask)
#     630     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 631     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     632
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2053                         # in the engines. This should return a list of strings.
# -> 2054                         stb = value._render_traceback_()
#    2055                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2055                     except Exception:
#    2056                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2057                                             value, tb, tb_offset=tb_offset)
#    2058
#    2059                     self._showtraceback(etype, value, stb)
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# c:\users\mcian\appdata\local\programs\python\python37\lib\site-packages\IPython\core\ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
train.to_csv('train_timeframes3.csv', index=True)
test.to_csv('test_timeframes3.csv', index=True)

# %%
train.to_csv('train_timeframes3.csv', index=True)
test.to_csv('test_timeframes3.csv', index=True)

# %%
train = pd.read_csv('train_timeframes2.csv')
test = pd.read_csv('test_timeframes2.csv')

# %%
import numpy as np
def normalize(data, window, step):
    result = []
    for frame in ['_1min', '_5min', '_15min', '_30min', '_60min']:
        values = [c for c in data.columns if frame in c]
        ohlc = data.iloc[step - window + 1:step + 1][values].copy()

        min_low = ohlc[values].min().min()
        for c in ohlc.columns:
            ohlc[c] -= min_low

        max_high = ohlc[values].max().max()
        for c in ohlc.columns:
            ohlc[c] /= max_high
        
        result.append(ohlc.values)
        
    return np.array(result)

# %%
window_size = 120

# %%
# %%time
inputs_train = []
for i in range(window_size-1, len(train)):
    if i % 1000 == 0:
        print(i)
    inputs_train.append(normalize(train, window_size , i))
inputs_train = np.array(inputs_train)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000
# 145000
# 146000
# 147000
# 148000
# 149000
# 150000
# 151000
# 152000
# 153000
# 154000
# 155000
# 156000
# 157000
# 158000
# 159000
# 160000
# 161000
# 162000
# 163000
# 164000
# 165000
# 166000
# 167000
# 168000
# 169000
# 170000
# 171000
# 172000
# 173000
# 174000
# 175000
# 176000
# 177000
# 178000
# 179000
# 180000
# 181000
# 182000
# 183000
# 184000
# 185000
# 186000
# 187000
# 188000
# 189000
# 190000
# 191000
# 192000
# 193000
# 194000
# 195000
# 196000
# 197000
# 198000
# 199000
# 200000
# 201000
# 202000
# 203000
# 204000
# 205000
# 206000
# 207000
# 208000
# 209000
# 210000
# 211000
# 212000
# 213000
# 214000
# 215000
# 216000
# 217000
# 218000
# 219000
# 220000
# 221000
# 222000
# 223000
# 224000
# 225000
# 226000
# 227000
# 228000
# 229000
# 230000
# 231000
# 232000
# 233000
# 234000
# 235000
# 236000
# 237000
# 238000
# 239000
# 240000
# 241000
# 242000
# 243000
# 244000
# 245000
# 246000
# 247000
# 248000
# 249000
# 250000
# 251000
# 252000
# 253000
# 254000
# 255000
# 256000
# 257000
# 258000
# 259000
# 260000
# 261000
# 262000
# 263000
# 264000
# 265000
# 266000
# 267000
# 268000
# 269000
# 270000
# 271000
# 272000
# 273000
# 274000
# 275000
# 276000
# 277000
# 278000
# 279000
# 280000
# 281000
# 282000
# 283000
# 284000
# 285000
# 286000
# 287000
# 288000
# 289000
# 290000
# 291000
# 292000
# 293000
# 294000
# 295000
# 296000
# 297000
# 298000
# 299000
# 300000
# 301000
# 302000
# 303000
# 304000
# 305000
# 306000
# 307000
# 308000
# 309000
# 310000
# 311000
# 312000
# 313000
# 314000
# 315000
# 316000
# 317000
# Wall time: 7h 32min 40s

# %%
# %%time
inputs_test = []
for i in range(window_size-1, len(test)):
    if i % 1000 == 0:
        print(i)
    inputs_test.append(normalize(test, window_size , i))
inputs_test = np.array(inputs_test)
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# Wall time: 47min 40s

# %%
inputs_train.shape, inputs_test.shape
# Out:
# ((317316, 5, 120, 5), (24305, 5, 120, 5))

# %%
np.save("inputs_train_120", inputs_train)
np.save("inputs_test_120", inputs_test)

# %%
train.plot(y='close_1min')
# Out:
# <AxesSubplot:>

# %%
inputs_train = np.transpose(inputs_train, (0, 2,3,1))
inputs_test = np.transpose(inputs_test, (0, 2,3,1))

# %%
inputs_train = inputs_train.reshape(inputs_train.shape[:2] + (inputs_train.shape[2]*inputs_train.shape[3],))
inputs_test = inputs_test.reshape(inputs_test.shape[:2] + (inputs_test.shape[2]*inputs_test.shape[3],))

# %%
all_closes_train = tf.convert_to_tensor([[train.iloc[i+j:i+j+time_limit]['close_1min'].tolist() for j in range(batch_size)] for i in range(len(train)-buffer)])
all_closes_test = tf.convert_to_tensor([[df[1].iloc[i+j:i+j+time_limit]['close_1min'].tolist() for j in range(batch_size)] for i in range(len(df[1])-buffer)])
