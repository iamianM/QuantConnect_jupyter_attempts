# %%
from os import listdir, walk
from os.path import isfile, join
import pandas as pd
import datetime

# %%
path = 'data/forex/oanda/minute/'
currencies = ['eurusd/'] #, 'audchf/']

# %%
files = []
for currency in currencies:
    files.append([f for f in listdir(path + currency) if 2016 <= int(f.split('_')[0][:4]) <= 2022])

# %%
files
# Out:
# [['20160103_quote.zip',
#   '20160104_quote.zip',
#   '20160105_quote.zip',
#   '20160106_quote.zip',
#   '20160107_quote.zip',
#   '20160108_quote.zip',
#   '20160110_quote.zip',
#   '20160111_quote.zip',
#   '20160112_quote.zip',
#   '20160113_quote.zip',
#   '20160114_quote.zip',
#   '20160115_quote.zip',
#   '20160117_quote.zip',
#   '20160118_quote.zip',
#   '20160119_quote.zip',
#   '20160120_quote.zip',
#   '20160121_quote.zip',
#   '20160122_quote.zip',
#   '20160124_quote.zip',
#   '20160125_quote.zip',
#   '20160126_quote.zip',
#   '20160127_quote.zip',
#   '20160128_quote.zip',
#   '20160129_quote.zip',
#   '20160131_quote.zip',
#   '20160201_quote.zip',
#   '20160202_quote.zip',
#   '20160203_quote.zip',
#   '20160204_quote.zip',
#   '20160205_quote.zip',
#   '20160207_quote.zip',
#   '20160208_quote.zip',
#   '20160209_quote.zip',
#   '20160210_quote.zip',
#   '20160211_quote.zip',
#   '20160212_quote.zip',
#   '20160214_quote.zip',
#   '20160215_quote.zip',
#   '20160216_quote.zip',
#   '20160217_quote.zip',
#   '20160218_quote.zip',
#   '20160219_quote.zip',
#   '20160221_quote.zip',
#   '20160222_quote.zip',
#   '20160223_quote.zip',
#   '20160224_quote.zip',
#   '20160225_quote.zip',
#   '20160226_quote.zip',
#   '20160228_quote.zip',
#   '20160229_quote.zip',
#   '20160301_quote.zip',
#   '20160302_quote.zip',
#   '20160303_quote.zip',
#   '20160304_quote.zip',
#   '20160306_quote.zip',
#   '20160307_quote.zip',
#   '20160308_quote.zip',
#   '20160309_quote.zip',
#   '20160310_quote.zip',
#   '20160311_quote.zip',
#   '20160313_quote.zip',
#   '20160314_quote.zip',
#   '20160315_quote.zip',
#   '20160316_quote.zip',
#   '20160317_quote.zip',
#   '20160318_quote.zip',
#   '20160320_quote.zip',
#   '20160321_quote.zip',
#   '20160322_quote.zip',
#   '20160323_quote.zip',
#   '20160324_quote.zip',
#   '20160325_quote.zip',
#   '20160327_quote.zip',
#   '20160328_quote.zip',
#   '20160329_quote.zip',
#   '20160330_quote.zip',
#   '20160331_quote.zip',
#   '20160401_quote.zip',
#   '20160403_quote.zip',
#   '20160404_quote.zip',
#   '20160405_quote.zip',
#   '20160406_quote.zip',
#   '20160407_quote.zip',
#   '20160408_quote.zip',
#   '20160410_quote.zip',
#   '20160411_quote.zip',
#   '20160412_quote.zip',
#   '20160413_quote.zip',
#   '20160414_quote.zip',
#   '20160415_quote.zip',
#   '20160417_quote.zip',
#   '20160418_quote.zip',
#   '20160419_quote.zip',
#   '20160420_quote.zip',
#   '20160421_quote.zip',
#   '20160422_quote.zip',
#   '20160424_quote.zip',
#   '20160425_quote.zip',
#   '20160426_quote.zip',
#   '20160427_quote.zip',
#   '20160428_quote.zip',
#   '20160429_quote.zip',
#   '20160501_quote.zip',
#   '20160502_quote.zip',
#   '20160503_quote.zip',
#   '20160504_quote.zip',
#   '20160505_quote.zip',
#   '20160506_quote.zip',
#   '20160508_quote.zip',
#   '20160509_quote.zip',
#   '20160510_quote.zip',
#   '20160511_quote.zip',
#   '20160512_quote.zip',
#   '20160513_quote.zip',
#   '20160515_quote.zip',
#   '20160516_quote.zip',
#   '20160517_quote.zip',
#   '20160518_quote.zip',
#   '20160519_quote.zip',
#   '20160520_quote.zip',
#   '20160522_quote.zip',
#   '20160523_quote.zip',
#   '20160524_quote.zip',
#   '20160525_quote.zip',
#   '20160526_quote.zip',
#   '20160527_quote.zip',
#   '20160529_quote.zip',
#   '20160530_quote.zip',
#   '20160531_quote.zip',
#   '20160601_quote.zip',
#   '20160602_quote.zip',
#   '20160603_quote.zip',
#   '20160605_quote.zip',
#   '20160606_quote.zip',
#   '20160607_quote.zip',
#   '20160608_quote.zip',
#   '20160609_quote.zip',
#   '20160610_quote.zip',
#   '20160612_quote.zip',
#   '20160613_quote.zip',
#   '20160614_quote.zip',
#   '20160615_quote.zip',
#   '20160616_quote.zip',
#   '20160617_quote.zip',
#   '20160619_quote.zip',
#   '20160620_quote.zip',
#   '20160621_quote.zip',
#   '20160622_quote.zip',
#   '20160623_quote.zip',
#   '20160624_quote.zip',
#   '20160626_quote.zip',
#   '20160627_quote.zip',
#   '20160628_quote.zip',
#   '20160629_quote.zip',
#   '20160630_quote.zip',
#   '20160701_quote.zip',
#   '20160703_quote.zip',
#   '20160704_quote.zip',
#   '20160705_quote.zip',
#   '20160706_quote.zip',
#   '20160707_quote.zip',
#   '20160708_quote.zip',
#   '20160710_quote.zip',
#   '20160711_quote.zip',
#   '20160712_quote.zip',
#   '20160713_quote.zip',
#   '20160714_quote.zip',
#   '20160715_quote.zip',
#   '20160717_quote.zip',
#   '20160718_quote.zip',
#   '20160719_quote.zip',
#   '20160720_quote.zip',
#   '20160721_quote.zip',
#   '20160722_quote.zip',
#   '20160724_quote.zip',
#   '20160725_quote.zip',
#   '20160726_quote.zip',
#   '20160727_quote.zip',
#   '20160728_quote.zip',
#   '20160729_quote.zip',
#   '20160731_quote.zip',
#   '20160801_quote.zip',
#   '20160802_quote.zip',
#   '20160803_quote.zip',
#   '20160804_quote.zip',
#   '20160805_quote.zip',
#   '20160807_quote.zip',
#   '20160808_quote.zip',
#   '20160809_quote.zip',
#   '20160810_quote.zip',
#   '20160811_quote.zip',
#   '20160812_quote.zip',
#   '20160814_quote.zip',
#   '20160815_quote.zip',
#   '20160816_quote.zip',
#   '20160817_quote.zip',
#   '20160818_quote.zip',
#   '20160819_quote.zip',
#   '20160821_quote.zip',
#   '20160822_quote.zip',
#   '20160823_quote.zip',
#   '20160824_quote.zip',
#   '20160825_quote.zip',
#   '20160826_quote.zip',
#   '20160828_quote.zip',
#   '20160829_quote.zip',
#   '20160830_quote.zip',
#   '20160831_quote.zip',
#   '20160901_quote.zip',
#   '20160902_quote.zip',
#   '20160904_quote.zip',
#   '20160905_quote.zip',
#   '20160906_quote.zip',
#   '20160907_quote.zip',
#   '20160908_quote.zip',
#   '20160909_quote.zip',
#   '20160911_quote.zip',
#   '20160912_quote.zip',
#   '20160913_quote.zip',
#   '20160914_quote.zip',
#   '20160915_quote.zip',
#   '20160916_quote.zip',
#   '20160918_quote.zip',
#   '20160919_quote.zip',
#   '20160920_quote.zip',
#   '20160921_quote.zip',
#   '20160922_quote.zip',
#   '20160923_quote.zip',
#   '20160925_quote.zip',
#   '20160926_quote.zip',
#   '20160927_quote.zip',
#   '20160928_quote.zip',
#   '20160929_quote.zip',
#   '20160930_quote.zip',
#   '20161002_quote.zip',
#   '20161003_quote.zip',
#   '20161004_quote.zip',
#   '20161005_quote.zip',
#   '20161006_quote.zip',
#   '20161007_quote.zip',
#   '20161009_quote.zip',
#   '20161010_quote.zip',
#   '20161011_quote.zip',
#   '20161012_quote.zip',
#   '20161013_quote.zip',
#   '20161014_quote.zip',
#   '20161016_quote.zip',
#   '20161017_quote.zip',
#   '20161018_quote.zip',
#   '20161019_quote.zip',
#   '20161020_quote.zip',
#   '20161021_quote.zip',
#   '20161023_quote.zip',
#   '20161024_quote.zip',
#   '20161025_quote.zip',
#   '20161026_quote.zip',
#   '20161027_quote.zip',
#   '20161028_quote.zip',
#   '20161030_quote.zip',
#   '20161031_quote.zip',
#   '20161101_quote.zip',
#   '20161102_quote.zip',
#   '20161103_quote.zip',
#   '20161104_quote.zip',
#   '20161106_quote.zip',
#   '20161107_quote.zip',
#   '20161108_quote.zip',
#   '20161109_quote.zip',
#   '20161110_quote.zip',
#   '20161111_quote.zip',
#   '20161113_quote.zip',
#   '20161114_quote.zip',
#   '20161115_quote.zip',
#   '20161116_quote.zip',
#   '20161117_quote.zip',
#   '20161118_quote.zip',
#   '20161120_quote.zip',
#   '20161121_quote.zip',
#   '20161122_quote.zip',
#   '20161123_quote.zip',
#   '20161124_quote.zip',
#   '20161125_quote.zip',
#   '20161127_quote.zip',
#   '20161128_quote.zip',
#   '20161129_quote.zip',
#   '20161130_quote.zip',
#   '20161201_quote.zip',
#   '20161202_quote.zip',
#   '20161204_quote.zip',
#   '20161205_quote.zip',
#   '20161206_quote.zip',
#   '20161207_quote.zip',
#   '20161208_quote.zip',
#   '20161209_quote.zip',
#   '20161216_quote.zip',
#   '20161218_quote.zip',
#   '20161219_quote.zip',
#   '20161220_quote.zip',
#   '20161221_quote.zip',
#   '20161222_quote.zip',
#   '20161223_quote.zip',
#   '20161226_quote.zip',
#   '20161227_quote.zip',
#   '20161228_quote.zip',
#   '20161229_quote.zip',
#   '20161230_quote.zip',
#   '20170102_quote.zip',
#   '20170103_quote.zip',
#   '20170104_quote.zip',
#   '20170105_quote.zip',
#   '20170106_quote.zip',
#   '20170108_quote.zip',
#   '20170109_quote.zip',
#   '20170110_quote.zip',
#   '20170111_quote.zip',
#   '20170112_quote.zip',
#   '20170113_quote.zip',
#   '20170115_quote.zip',
#   '20170116_quote.zip',
#   '20170117_quote.zip',
#   '20170118_quote.zip',
#   '20170119_quote.zip',
#   '20170120_quote.zip',
#   '20170122_quote.zip',
#   '20170123_quote.zip',
#   '20170124_quote.zip',
#   '20170125_quote.zip',
#   '20170126_quote.zip',
#   '20170127_quote.zip',
#   '20170129_quote.zip',
#   '20170130_quote.zip',
#   '20170131_quote.zip',
#   '20170201_quote.zip',
#   '20170202_quote.zip',
#   '20170203_quote.zip',
#   '20170205_quote.zip',
#   '20170206_quote.zip',
#   '20170207_quote.zip',
#   '20170208_quote.zip',
#   '20170209_quote.zip',
#   '20170210_quote.zip',
#   '20170212_quote.zip',
#   '20170213_quote.zip',
#   '20170214_quote.zip',
#   '20170215_quote.zip',
#   '20170216_quote.zip',
#   '20170217_quote.zip',
#   '20170219_quote.zip',
#   '20170220_quote.zip',
#   '20170221_quote.zip',
#   '20170222_quote.zip',
#   '20170223_quote.zip',
#   '20170224_quote.zip',
#   '20170226_quote.zip',
#   '20170227_quote.zip',
#   '20170228_quote.zip',
#   '20170301_quote.zip',
#   '20170302_quote.zip',
#   '20170303_quote.zip',
#   '20170305_quote.zip',
#   '20170306_quote.zip',
#   '20170307_quote.zip',
#   '20170308_quote.zip',
#   '20170309_quote.zip',
#   '20170310_quote.zip',
#   '20170312_quote.zip',
#   '20170313_quote.zip',
#   '20170314_quote.zip',
#   '20170315_quote.zip',
#   '20170316_quote.zip',
#   '20170317_quote.zip',
#   '20170319_quote.zip',
#   '20170320_quote.zip',
#   '20170321_quote.zip',
#   '20170322_quote.zip',
#   '20170323_quote.zip',
#   '20170324_quote.zip',
#   '20170326_quote.zip',
#   '20170327_quote.zip',
#   '20170328_quote.zip',
#   '20170329_quote.zip',
#   '20170330_quote.zip',
#   '20170331_quote.zip',
#   '20170402_quote.zip',
#   '20170403_quote.zip',
#   '20170404_quote.zip',
#   '20170405_quote.zip',
#   '20170406_quote.zip',
#   '20170407_quote.zip',
#   '20170409_quote.zip',
#   '20170410_quote.zip',
#   '20170411_quote.zip',
#   '20170412_quote.zip',
#   '20170413_quote.zip',
#   '20170414_quote.zip',
#   '20170416_quote.zip',
#   '20170417_quote.zip',
#   '20170418_quote.zip',
#   '20170419_quote.zip',
#   '20170420_quote.zip',
#   '20170421_quote.zip',
#   '20170423_quote.zip',
#   '20170424_quote.zip',
#   '20170425_quote.zip',
#   '20170426_quote.zip',
#   '20170427_quote.zip',
#   '20170428_quote.zip',
#   '20170430_quote.zip',
#   '20170501_quote.zip',
#   '20170502_quote.zip',
#   '20170503_quote.zip',
#   '20170504_quote.zip',
#   '20170505_quote.zip',
#   '20170507_quote.zip',
#   '20170508_quote.zip',
#   '20170509_quote.zip',
#   '20170510_quote.zip',
#   '20170511_quote.zip',
#   '20170512_quote.zip',
#   '20170514_quote.zip',
#   '20170515_quote.zip',
#   '20170516_quote.zip',
#   '20170517_quote.zip',
#   '20170518_quote.zip',
#   '20170519_quote.zip',
#   '20170521_quote.zip',
#   '20170522_quote.zip',
#   '20170523_quote.zip',
#   '20170524_quote.zip',
#   '20170525_quote.zip',
#   '20170526_quote.zip',
#   '20170528_quote.zip',
#   '20170529_quote.zip',
#   '20170530_quote.zip',
#   '20170531_quote.zip',
#   '20170601_quote.zip',
#   '20170602_quote.zip',
#   '20170604_quote.zip',
#   '20170605_quote.zip',
#   '20170606_quote.zip',
#   '20170607_quote.zip',
#   '20170608_quote.zip',
#   '20170609_quote.zip',
#   '20170611_quote.zip',
#   '20170612_quote.zip',
#   '20170613_quote.zip',
#   '20170614_quote.zip',
#   '20170615_quote.zip',
#   '20170616_quote.zip',
#   '20170618_quote.zip',
#   '20170619_quote.zip',
#   '20170620_quote.zip',
#   '20170621_quote.zip',
#   '20170622_quote.zip',
#   '20170623_quote.zip',
#   '20170625_quote.zip',
#   '20170626_quote.zip',
#   '20170627_quote.zip',
#   '20170628_quote.zip',
#   '20170629_quote.zip',
#   '20170630_quote.zip',
#   '20170702_quote.zip',
#   '20170703_quote.zip',
#   '20170704_quote.zip',
#   '20170705_quote.zip',
#   '20170706_quote.zip',
#   '20170707_quote.zip',
#   '20170709_quote.zip',
#   '20170710_quote.zip',
#   '20170711_quote.zip',
#   '20170712_quote.zip',
#   '20170713_quote.zip',
#   '20170714_quote.zip',
#   '20170716_quote.zip',
#   '20170717_quote.zip',
#   '20170718_quote.zip',
#   '20170719_quote.zip',
#   '20170720_quote.zip',
#   '20170721_quote.zip',
#   '20170723_quote.zip',
#   '20170724_quote.zip',
#   '20170725_quote.zip',
#   '20170726_quote.zip',
#   '20170727_quote.zip',
#   '20170728_quote.zip',
#   '20170730_quote.zip',
#   '20170731_quote.zip',
#   '20170801_quote.zip',
#   '20170802_quote.zip',
#   '20170803_quote.zip',
#   '20170804_quote.zip',
#   '20170806_quote.zip',
#   '20170807_quote.zip',
#   '20170808_quote.zip',
#   '20170809_quote.zip',
#   '20170810_quote.zip',
#   '20170811_quote.zip',
#   '20170813_quote.zip',
#   '20170814_quote.zip',
#   '20170815_quote.zip',
#   '20170816_quote.zip',
#   '20170817_quote.zip',
#   '20170818_quote.zip',
#   '20170820_quote.zip',
#   '20170821_quote.zip',
#   '20170822_quote.zip',
#   '20170823_quote.zip',
#   '20170824_quote.zip',
#   '20170825_quote.zip',
#   '20170827_quote.zip',
#   '20170828_quote.zip',
#   '20170829_quote.zip',
#   '20170830_quote.zip',
#   '20170831_quote.zip',
#   '20170901_quote.zip',
#   '20170903_quote.zip',
#   '20170904_quote.zip',
#   '20170905_quote.zip',
#   '20170906_quote.zip',
#   '20170907_quote.zip',
#   '20170908_quote.zip',
#   '20170910_quote.zip',
#   '20170911_quote.zip',
#   '20170912_quote.zip',
#   '20170913_quote.zip',
#   '20170914_quote.zip',
#   '20170915_quote.zip',
#   '20170917_quote.zip',
#   '20170918_quote.zip',
#   '20170919_quote.zip',
#   '20170920_quote.zip',
#   '20170921_quote.zip',
#   '20170922_quote.zip',
#   '20170924_quote.zip',
#   '20170925_quote.zip',
#   '20170926_quote.zip',
#   '20170927_quote.zip',
#   '20170928_quote.zip',
#   '20170929_quote.zip',
#   '20171001_quote.zip',
#   '20171002_quote.zip',
#   '20171003_quote.zip',
#   '20171004_quote.zip',
#   '20171005_quote.zip',
#   '20171006_quote.zip',
#   '20171008_quote.zip',
#   '20171009_quote.zip',
#   '20171010_quote.zip',
#   '20171011_quote.zip',
#   '20171012_quote.zip',
#   '20171013_quote.zip',
#   '20171015_quote.zip',
#   '20171016_quote.zip',
#   '20171017_quote.zip',
#   '20171018_quote.zip',
#   '20171019_quote.zip',
#   '20171020_quote.zip',
#   '20171022_quote.zip',
#   '20171023_quote.zip',
#   '20171024_quote.zip',
#   '20171025_quote.zip',
#   '20171026_quote.zip',
#   '20171027_quote.zip',
#   '20171029_quote.zip',
#   '20171030_quote.zip',
#   '20171031_quote.zip',
#   '20171101_quote.zip',
#   '20171102_quote.zip',
#   '20171103_quote.zip',
#   '20171105_quote.zip',
#   '20171106_quote.zip',
#   '20171107_quote.zip',
#   '20171108_quote.zip',
#   '20171109_quote.zip',
#   '20171110_quote.zip',
#   '20171112_quote.zip',
#   '20171113_quote.zip',
#   '20171114_quote.zip',
#   '20171115_quote.zip',
#   '20171116_quote.zip',
#   '20171117_quote.zip',
#   '20171119_quote.zip',
#   '20171120_quote.zip',
#   '20171121_quote.zip',
#   '20171122_quote.zip',
#   '20171123_quote.zip',
#   '20171124_quote.zip',
#   '20171126_quote.zip',
#   '20171127_quote.zip',
#   '20171128_quote.zip',
#   '20171129_quote.zip',
#   '20171130_quote.zip',
#   '20171201_quote.zip',
#   '20171203_quote.zip',
#   '20171204_quote.zip',
#   '20171205_quote.zip',
#   '20171206_quote.zip',
#   '20171207_quote.zip',
#   '20171208_quote.zip',
#   '20171210_quote.zip',
#   '20171211_quote.zip',
#   '20171212_quote.zip',
#   '20171213_quote.zip',
#   '20171214_quote.zip',
#   '20171215_quote.zip',
#   '20171217_quote.zip',
#   '20171218_quote.zip',
#   '20171219_quote.zip',
#   '20171220_quote.zip',
#   '20171221_quote.zip',
#   '20171222_quote.zip',
#   '20171226_quote.zip',
#   '20171227_quote.zip',
#   '20171228_quote.zip',
#   '20171229_quote.zip',
#   '20180102_quote.zip',
#   '20180103_quote.zip',
#   '20180104_quote.zip',
#   '20180105_quote.zip',
#   '20180107_quote.zip',
#   '20180108_quote.zip',
#   '20180109_quote.zip',
#   '20180110_quote.zip',
#   '20180111_quote.zip',
#   '20180112_quote.zip',
#   '20180114_quote.zip',
#   '20180115_quote.zip',
#   '20180116_quote.zip',
#   '20180117_quote.zip',
#   '20180118_quote.zip',
#   '20180119_quote.zip',
#   '20180121_quote.zip',
#   '20180122_quote.zip',
#   '20180123_quote.zip',
#   '20180124_quote.zip',
#   '20180125_quote.zip',
#   '20180126_quote.zip',
#   '20180128_quote.zip',
#   '20180129_quote.zip',
#   '20180130_quote.zip',
#   '20180131_quote.zip',
#   '20180201_quote.zip',
#   '20180202_quote.zip',
#   '20180204_quote.zip',
#   '20180205_quote.zip',
#   '20180206_quote.zip',
#   '20180207_quote.zip',
#   '20180208_quote.zip',
#   '20180209_quote.zip',
#   '20180211_quote.zip',
#   '20180212_quote.zip',
#   '20180213_quote.zip',
#   '20180214_quote.zip',
#   '20180215_quote.zip',
#   '20180216_quote.zip',
#   '20180218_quote.zip',
#   '20180219_quote.zip',
#   '20180220_quote.zip',
#   '20180221_quote.zip',
#   '20180222_quote.zip',
#   '20180223_quote.zip',
#   '20180225_quote.zip',
#   '20180226_quote.zip',
#   '20180227_quote.zip',
#   '20180228_quote.zip',
#   '20180301_quote.zip',
#   '20180302_quote.zip',
#   '20180304_quote.zip',
#   '20180305_quote.zip',
#   '20180306_quote.zip',
#   '20180307_quote.zip',
#   '20180308_quote.zip',
#   '20180309_quote.zip',
#   '20180311_quote.zip',
#   '20180312_quote.zip',
#   '20180313_quote.zip',
#   '20180314_quote.zip',
#   '20180315_quote.zip',
#   '20180316_quote.zip',
#   '20180318_quote.zip',
#   '20180319_quote.zip',
#   '20180320_quote.zip',
#   '20180321_quote.zip',
#   '20180322_quote.zip',
#   '20180323_quote.zip',
#   '20180325_quote.zip',
#   '20180326_quote.zip',
#   '20180327_quote.zip',
#   '20180328_quote.zip',
#   '20180329_quote.zip',
#   '20180330_quote.zip',
#   '20180401_quote.zip',
#   '20180402_quote.zip',
#   '20180403_quote.zip',
#   '20180404_quote.zip',
#   '20180405_quote.zip',
#   '20180406_quote.zip',
#   '20180408_quote.zip',
#   '20180409_quote.zip',
#   '20180410_quote.zip',
#   '20180411_quote.zip',
#   '20180412_quote.zip',
#   '20180413_quote.zip',
#   '20180415_quote.zip',
#   '20180416_quote.zip',
#   '20180417_quote.zip',
#   '20180418_quote.zip',
#   '20180419_quote.zip',
#   '20180420_quote.zip',
#   '20180422_quote.zip',
#   '20180423_quote.zip',
#   '20180424_quote.zip',
#   '20180425_quote.zip',
#   '20180426_quote.zip',
#   '20180427_quote.zip',
#   '20180429_quote.zip',
#   '20180430_quote.zip',
#   '20180501_quote.zip',
#   '20180502_quote.zip',
#   '20180503_quote.zip',
#   '20180504_quote.zip',
#   '20180506_quote.zip',
#   '20180507_quote.zip',
#   '20180508_quote.zip',
#   '20180509_quote.zip',
#   '20180510_quote.zip',
#   '20180511_quote.zip',
#   '20180513_quote.zip',
#   '20180514_quote.zip',
#   '20180515_quote.zip',
#   '20180516_quote.zip',
#   '20180517_quote.zip',
#   '20180518_quote.zip',
#   '20180520_quote.zip',
#   '20180521_quote.zip',
#   '20180522_quote.zip',
#   '20180523_quote.zip',
#   '20180524_quote.zip',
#   '20180525_quote.zip',
#   '20180527_quote.zip',
#   '20180528_quote.zip',
#   '20180529_quote.zip',
#   '20180530_quote.zip',
#   '20180531_quote.zip',
#   '20180601_quote.zip',
#   '20180603_quote.zip',
#   '20180604_quote.zip',
#   '20180605_quote.zip',
#   '20180606_quote.zip',
#   '20180607_quote.zip',
#   '20180608_quote.zip',
#   '20180610_quote.zip',
#   '20180611_quote.zip',
#   '20180612_quote.zip',
#   '20180613_quote.zip',
#   '20180614_quote.zip',
#   '20180615_quote.zip',
#   '20180617_quote.zip',
#   '20180618_quote.zip',
#   '20180619_quote.zip',
#   '20180620_quote.zip',
#   '20180621_quote.zip',
#   '20180622_quote.zip',
#   '20180624_quote.zip',
#   '20180625_quote.zip',
#   '20180626_quote.zip',
#   '20180627_quote.zip',
#   '20180628_quote.zip',
#   '20180629_quote.zip',
#   '20180701_quote.zip',
#   '20180702_quote.zip',
#   '20180703_quote.zip',
#   '20180704_quote.zip',
#   '20180705_quote.zip',
#   '20180706_quote.zip',
#   '20180708_quote.zip',
#   '20180709_quote.zip',
#   '20180710_quote.zip',
#   '20180711_quote.zip',
#   '20180712_quote.zip',
#   '20180713_quote.zip',
#   '20180715_quote.zip',
#   '20180716_quote.zip',
#   '20180717_quote.zip',
#   '20180718_quote.zip',
#   '20180719_quote.zip',
#   '20180720_quote.zip',
#   '20180722_quote.zip',
#   '20180723_quote.zip',
#   '20180724_quote.zip',
#   '20180725_quote.zip',
#   '20180726_quote.zip',
#   '20180727_quote.zip',
#   '20180729_quote.zip',
#   '20180730_quote.zip',
#   '20180731_quote.zip',
#   '20180801_quote.zip',
#   '20180802_quote.zip',
#   '20180803_quote.zip',
#   '20180805_quote.zip',
#   '20180806_quote.zip',
#   '20180807_quote.zip',
#   '20180808_quote.zip',
#   '20180809_quote.zip',
#   '20180810_quote.zip',
#   '20180812_quote.zip',
#   '20180813_quote.zip',
#   '20180814_quote.zip',
#   '20180815_quote.zip',
#   '20180816_quote.zip',
#   '20180817_quote.zip',
#   '20180819_quote.zip',
#   '20180820_quote.zip',
#   '20180821_quote.zip',
#   '20180822_quote.zip',
#   '20180823_quote.zip',
#   '20180824_quote.zip',
#   '20180826_quote.zip',
#   '20180827_quote.zip',
#   '20180828_quote.zip',
#   '20180829_quote.zip',
#   '20180830_quote.zip',
#   '20180831_quote.zip',
#   '20180902_quote.zip',
#   '20180903_quote.zip',
#   '20180904_quote.zip',
#   '20180905_quote.zip',
#   '20180906_quote.zip',
#   '20180907_quote.zip',
#   '20180909_quote.zip',
#   '20180910_quote.zip',
#   '20180911_quote.zip',
#   '20180912_quote.zip',
#   '20180913_quote.zip',
#   '20180914_quote.zip',
#   '20180916_quote.zip',
#   '20180917_quote.zip',
#   '20180918_quote.zip',
#   '20180919_quote.zip',
#   '20180920_quote.zip',
#   '20180921_quote.zip',
#   '20180923_quote.zip',
#   '20180924_quote.zip',
#   '20180925_quote.zip',
#   '20180926_quote.zip',
#   '20180927_quote.zip',
#   '20180928_quote.zip',
#   '20180930_quote.zip',
#   '20181001_quote.zip',
#   '20181002_quote.zip',
#   '20181003_quote.zip',
#   '20181004_quote.zip',
#   '20181005_quote.zip',
#   '20181007_quote.zip',
#   '20181008_quote.zip',
#   '20181009_quote.zip',
#   '20181010_quote.zip',
#   '20181011_quote.zip',
#   '20181012_quote.zip',
#   '20181014_quote.zip',
#   '20181015_quote.zip',
#   '20181016_quote.zip',
#   '20181017_quote.zip',
#   '20181018_quote.zip',
#   '20181019_quote.zip',
#   '20181021_quote.zip',
#   '20181022_quote.zip',
#   '20181023_quote.zip',
#   '20181024_quote.zip',
#   '20181025_quote.zip',
#   '20181026_quote.zip',
#   '20181029_quote.zip',
#   '20181030_quote.zip',
#   '20181031_quote.zip',
#   '20181101_quote.zip',
#   '20181102_quote.zip',
#   '20181104_quote.zip',
#   '20181105_quote.zip',
#   '20181106_quote.zip',
#   '20181107_quote.zip',
#   '20181108_quote.zip',
#   '20181109_quote.zip',
#   '20181111_quote.zip',
#   '20181112_quote.zip',
#   '20181113_quote.zip',
#   '20181114_quote.zip',
#   '20181115_quote.zip',
#   '20181116_quote.zip',
#   '20181118_quote.zip',
#   '20181119_quote.zip',
#   '20181120_quote.zip',
#   '20181121_quote.zip',
#   '20181122_quote.zip',
#   '20181123_quote.zip',
#   '20181125_quote.zip',
#   '20181126_quote.zip',
#   '20181127_quote.zip',
#   '20181128_quote.zip',
#   '20181129_quote.zip',
#   '20181130_quote.zip',
#   '20181202_quote.zip',
#   '20181203_quote.zip',
#   '20181204_quote.zip',
#   '20181205_quote.zip',
#   '20181206_quote.zip',
#   '20181207_quote.zip',
#   '20181209_quote.zip',
#   '20181210_quote.zip',
#   '20181211_quote.zip',
#   '20181212_quote.zip',
#   '20181213_quote.zip',
#   '20181214_quote.zip',
#   '20181216_quote.zip',
#   '20181217_quote.zip',
#   '20181218_quote.zip',
#   '20181219_quote.zip',
#   '20181220_quote.zip',
#   '20181221_quote.zip',
#   '20181223_quote.zip',
#   '20181224_quote.zip',
#   '20181227_quote.zip',
#   '20181228_quote.zip',
#   '20181230_quote.zip',
#   '20181231_quote.zip',
#   '20190102_quote.zip',
#   '20190103_quote.zip',
#   '20190104_quote.zip',
#   '20190106_quote.zip',
#   '20190107_quote.zip',
#   '20190108_quote.zip',
#   '20190109_quote.zip',
#   '20190110_quote.zip',
#   '20190111_quote.zip',
#   '20190113_quote.zip',
#   '20190114_quote.zip',
#   '20190115_quote.zip',
#   '20190116_quote.zip',
#   '20190117_quote.zip',
#   '20190118_quote.zip',
#   '20190120_quote.zip',
#   '20190121_quote.zip',
#   '20190122_quote.zip',
#   '20190123_quote.zip',
#   '20190124_quote.zip',
#   '20190125_quote.zip',
#   '20190127_quote.zip',
#   '20190128_quote.zip',
#   '20190129_quote.zip',
#   '20190130_quote.zip',
#   '20190131_quote.zip',
#   '20190201_quote.zip',
#   '20190203_quote.zip',
#   '20190204_quote.zip',
#   '20190205_quote.zip',
#   '20190206_quote.zip',
#   '20190207_quote.zip',
#   '20190208_quote.zip',
#   '20190210_quote.zip',
#   '20190211_quote.zip',
#   '20190212_quote.zip',
#   '20190213_quote.zip',
#   '20190214_quote.zip',
#   '20190215_quote.zip',
#   '20190217_quote.zip',
#   '20190218_quote.zip',
#   '20190219_quote.zip',
#   '20190220_quote.zip',
#   '20190221_quote.zip',
#   '20190222_quote.zip',
#   '20190224_quote.zip',
#   '20190225_quote.zip',
#   '20190226_quote.zip',
#   '20190227_quote.zip',
#   '20190228_quote.zip',
#   '20190301_quote.zip',
#   '20190303_quote.zip',
#   '20190304_quote.zip',
#   '20190305_quote.zip',
#   '20190306_quote.zip',
#   '20190307_quote.zip',
#   '20190308_quote.zip',
#   '20190310_quote.zip',
#   '20190311_quote.zip',
#   '20190312_quote.zip',
#   '20190313_quote.zip',
#   '20190314_quote.zip',
#   '20190315_quote.zip',
#   '20190317_quote.zip',
#   '20190318_quote.zip',
#   '20190319_quote.zip',
#   '20190320_quote.zip',
#   '20190321_quote.zip',
#   '20190322_quote.zip',
#   '20190324_quote.zip',
#   '20190325_quote.zip',
#   '20190326_quote.zip',
#   '20190327_quote.zip',
#   '20190328_quote.zip',
#   '20190329_quote.zip',
#   '20190331_quote.zip',
#   ...]]

# %%
import datetime
def convert_to_time(t):
    t /= 1000
    seconds = int(t%60)
    t /= 60
    minutes = int(t%60)
    t /= 60
    hours = int(t%24)
    return datetime.time(hours, minutes, seconds)

# %%
import talib

INDICATORS = {
    'BBANDS': {'method': 'BBANDS', 'period': 20}, 'SMA_SLOW': {'method': 'SMA', 'period': 200},
    'SMA_FAST': {'method': 'SMA', 'period': 50}, 'EMA_SLOW': {'method': 'EMA', 'period': 20},
    'EMA_FAST': {'method': 'EMA', 'period': 9}, 'ATR': {'method': 'ATR', 'period': 14},
    'RSI': {'method': 'RSI', 'period': 14}
}

def get_indicators(df, frame='1min'):
    df = df.copy()
    opens = df[f'open_{frame}'].values
    highs = df[f'high_{frame}'].values
    lows = df[f'low_{frame}'].values
    closes = df[f'close_{frame}'].values
    # Add indicator columns to DataFrame
    for indicator_name, indicator_values in INDICATORS.items():
        if indicator_name == 'BBANDS':
            ub, _, lb = getattr(talib, indicator_values['method'])(closes, indicator_values['period'])
            df[f'{indicator_name}_UB_{frame}'], df[f'{indicator_name}_LB_{frame}'] = ub, lb
        elif indicator_name == 'ATR':
            df[f"{indicator_name}_{frame}"] = \
                getattr(talib, indicator_values['method'])(highs,
                                                           lows,
                                                           closes,
                                                           indicator_values['period'])
        else:
            df[f"{indicator_name}_{frame}"] = getattr(talib, indicator_values['method'])(closes,
                                                                             indicator_values['period'])
    return df

# %%
PATTERNS = ["CDLSHOOTINGSTAR", "CDLDOJI", "CDLHAMMER", "CDLMORNINGSTAR", "CDLENGULFING", "CDLHARAMI", "CDLHANGINGMAN",
           "CDLDARKCLOUDCOVER", "CDLINVERTEDHAMMER", "CDLPIERCING", "CDLMORNINGDOJISTAR", "CDLDOJISTAR", "CDLEVENINGSTAR",
           "CDLEVENINGDOJISTAR", "CDLSPINNINGTOP", "CDL2CROWS", "CDL3BLACKCROWS", "CDL3WHITESOLDIERS", "CDLHARAMICROSS"]

def get_cdls(df, frame='1min'):
    df = df.copy()
    opens = df[f'open_{frame}'].values
    highs = df[f'high_{frame}'].values
    lows = df[f'low_{frame}'].values
    closes = df[f'close_{frame}'].values
    # Add indicator columns to DataFrame
    for pattern in PATTERNS:
        df[f"{pattern}_{frame}"] = getattr(talib, indicator_values['method'])(opens, highs, lows, closes)
    return df

# %%
def cumsample(x):
    if x.shape[0] == 0:
        return pd.DataFrame()
    else:
        return pd.DataFrame({'open': [x['open_1min'].iloc[0]]*len(x), 'close': x['close_1min'], 'close_bid': x['close_bid_1min'], 'high': x['close_1min'].cummax(), 'low': x['close_1min'].cummin()})

# %%
train = pd.DataFrame()
test = pd.DataFrame()
sizes = []
for j, currency in enumerate(currencies):
    print(currency)
    for i, f in enumerate(files[j]):
        if (i+1) % 100 == 0:
            print(i)
        date = f.split('_')[0]
        temp = pd.read_csv(path+currency+f, names=['time', 'open_bid', 'high_bid', 'low_bid', 'close_bid', 'volume', 'open_ask', 'high_ask', 'low_ask', 'close_ask', 'volume2'])
        sizes.append(temp.shape[0])
        if temp.shape[0] < 1400:
            continue
        del temp['volume']
        del temp['volume2']
        temp['date'] = date
        temp['time'] = temp['time'].apply(convert_to_time)
    #     temp = temp[temp['time'].apply(lambda x: datetime.time(12) < x < datetime.time(20))]
        temp['datetime'] = temp['time'].apply(lambda x: datetime.datetime(int(date[:4]), int(date[4:6]), int(date[6:]), x.hour, x.minute, x.second, tzinfo=datetime.timezone.utc))

        symbol = currency[:3].upper()
        temp['spread'] = temp['close_ask'] - temp['close_bid']
        for c in temp.columns:
            if c.endswith('ask'):
                temp[c[:-4]+'_1min'] = temp[c]
                del temp[c]
            elif c.endswith('bid'):
                if c.startswith('close'):
                    temp[c+'_1min'] = temp[c]
                    del temp[c]
                else:
                    del temp[c]
                    
        temp['day_high'] = temp['close_1min'].cummax()
        temp['day_low'] = temp['close_1min'].cummin()
        if i != 0:
            temp['previous_close'] = temp_prev['close_1min'].iloc[-1]
            temp['previous_high'] = temp_prev['close_1min'].max()
            temp['previous_low'] = temp_prev['close_1min'].min()
        else:
            temp['previous_close'] = None
            temp['previous_high'] = None
            temp['previous_low'] = None
            
        temp_prev = temp.copy()
                    
        if f.startswith('2021'):
            test = pd.concat([test, temp])
        else:
            train = pd.concat([train, temp])
# Out:
# eurusd/
# 99
# 199
# 299
# 399
# 499
# 599
# 699
# 799
# 899
# 999
# 1099
# 1199
# 1299
# 1399
# 1499
# 1599

# %%
timeframes = ['5min', '30min']

train = get_indicators(train, frame='1min')
train.set_index('datetime', inplace=True)
dfs = pd.DataFrame()
for frame in timeframes:
    df = train.resample(frame).apply(cumsample)
    if type(df.index) == pd.core.indexes.multi.MultiIndex:
        df.index = df.index.droplevel()
    df.columns = [c+'_'+frame for c in df.columns]
    df = get_indicators(df, frame=frame)
    dfs = pd.concat([dfs, df], axis=1)
train = pd.concat([train, dfs], axis=1)

test = get_indicators(test, frame='1min')
test.set_index('datetime', inplace=True)
dfs = pd.DataFrame()
for frame in timeframes:
    df = test.resample(frame).apply(cumsample)
    if type(df.index) == pd.core.indexes.multi.MultiIndex:
        df.index = df.index.droplevel()
    df.columns = [c+'_'+frame for c in df.columns]
    df = get_indicators(df, frame=frame)
    dfs = pd.concat([dfs, df], axis=1)
test = pd.concat([test, dfs], axis=1)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 940140 entries, 0 to 1409
# Data columns (total 14 columns):
# time              940140 non-null object
# date              940140 non-null object
# datetime          940140 non-null datetime64[ns, UTC]
# spread            940140 non-null float64
# close_bid_1min    940140 non-null float64
# open_1min         940140 non-null float64
# high_1min         940140 non-null float64
# low_1min          940140 non-null float64
# close_1min        940140 non-null float64
# day_high          940140 non-null float64
# day_low           940140 non-null float64
# previous_close    940140 non-null float64
# previous_high     940140 non-null float64
# previous_low      940140 non-null float64
# dtypes: datetime64[ns, UTC](1), float64(11), object(2)
# memory usage: 107.6+ MB

# %%
train
# Out:
#           time      date                  datetime   spread  close_bid_1min  \
# 0     00:00:00  20160104 2016-01-04 00:00:00+00:00  0.00019         1.08556
# 1     00:01:00  20160104 2016-01-04 00:01:00+00:00  0.00018         1.08539
# 2     00:02:00  20160104 2016-01-04 00:02:00+00:00  0.00019         1.08548
# 3     00:03:00  20160104 2016-01-04 00:03:00+00:00  0.00018         1.08546
# 4     00:04:00  20160104 2016-01-04 00:04:00+00:00  0.00019         1.08543
# ...        ...       ...                       ...      ...             ...
# 1405  23:52:00  20201230 2020-12-30 23:52:00+00:00  0.00014         1.22989
# 1406  23:56:00  20201230 2020-12-30 23:56:00+00:00  0.00014         1.22989
# 1407  23:57:00  20201230 2020-12-30 23:57:00+00:00  0.00012         1.22990
# 1408  23:58:00  20201230 2020-12-30 23:58:00+00:00  0.00013         1.22991
# 1409  23:59:00  20201230 2020-12-30 23:59:00+00:00  0.00015         1.22979
#
#       open_1min  high_1min  low_1min  close_1min  day_high  day_low  \
# 0       1.08528    1.08578   1.08527     1.08575   1.08575  1.08575
# 1       1.08577    1.08590   1.08557     1.08557   1.08575  1.08557
# 2       1.08558    1.08569   1.08558     1.08567   1.08575  1.08557
# 3       1.08563    1.08564   1.08562     1.08564   1.08575  1.08557
# 4       1.08562    1.08562   1.08562     1.08562   1.08575  1.08557
# ...         ...        ...       ...         ...       ...      ...
# 1405    1.23001    1.23005   1.23001     1.23003   1.23094  1.22526
# 1406    1.23003    1.23003   1.23001     1.23003   1.23094  1.22526
# 1407    1.23003    1.23003   1.23002     1.23002   1.23094  1.22526
# 1408    1.23002    1.23006   1.23002     1.23004   1.23094  1.22526
# 1409    1.23004    1.23004   1.22993     1.22994   1.23094  1.22526
#
#       previous_close  previous_high  previous_low
# 0            1.10647        1.11849       1.10607
# 1            1.10647        1.11849       1.10607
# 2            1.10647        1.11849       1.10607
# 3            1.10647        1.11849       1.10607
# 4            1.10647        1.11849       1.10607
# ...              ...            ...           ...
# 1405         1.22531        1.22754       1.22212
# 1406         1.22531        1.22754       1.22212
# 1407         1.22531        1.22754       1.22212
# 1408         1.22531        1.22754       1.22212
# 1409         1.22531        1.22754       1.22212
#
# [940140 rows x 14 columns]

# %%
# del train['Unnamed: 0']
# del test['Unnamed: 0']
train.dropna(inplace=True)
test.dropna(inplace=True)

# %%
len(train), len(test)
# Out:
# (939941, 71887)

# %%
train
# Out:
#                                time      date   spread  close_bid_1min  \
# datetime
# 2016-01-04 03:23:00+00:00  03:23:00  20160104  0.00017         1.08696
# 2016-01-04 03:24:00+00:00  03:24:00  20160104  0.00018         1.08685
# 2016-01-04 03:25:00+00:00  03:25:00  20160104  0.00018         1.08698
# 2016-01-04 03:26:00+00:00  03:26:00  20160104  0.00016         1.08694
# 2016-01-04 03:27:00+00:00  03:27:00  20160104  0.00017         1.08701
# ...                             ...       ...      ...             ...
# 2020-12-30 23:52:00+00:00  23:52:00  20201230  0.00014         1.22989
# 2020-12-30 23:56:00+00:00  23:56:00  20201230  0.00014         1.22989
# 2020-12-30 23:57:00+00:00  23:57:00  20201230  0.00012         1.22990
# 2020-12-30 23:58:00+00:00  23:58:00  20201230  0.00013         1.22991
# 2020-12-30 23:59:00+00:00  23:59:00  20201230  0.00015         1.22979
#
#                            open_1min  high_1min  low_1min  close_1min  \
# datetime
# 2016-01-04 03:23:00+00:00    1.08720    1.08729   1.08713     1.08713
# 2016-01-04 03:24:00+00:00    1.08710    1.08710   1.08703     1.08703
# 2016-01-04 03:25:00+00:00    1.08704    1.08718   1.08704     1.08716
# 2016-01-04 03:26:00+00:00    1.08714    1.08714   1.08707     1.08710
# 2016-01-04 03:27:00+00:00    1.08711    1.08718   1.08707     1.08718
# ...                              ...        ...       ...         ...
# 2020-12-30 23:52:00+00:00    1.23001    1.23005   1.23001     1.23003
# 2020-12-30 23:56:00+00:00    1.23003    1.23003   1.23001     1.23003
# 2020-12-30 23:57:00+00:00    1.23003    1.23003   1.23002     1.23002
# 2020-12-30 23:58:00+00:00    1.23002    1.23006   1.23002     1.23004
# 2020-12-30 23:59:00+00:00    1.23004    1.23004   1.22993     1.22994
#
#                            BBANDS_UB_1min  BBANDS_LB_1min  ...  high_30min  \
# datetime                                                   ...
# 2016-01-04 03:23:00+00:00        1.087235        1.086945  ...     1.08738
# 2016-01-04 03:24:00+00:00        1.087206        1.086952  ...     1.08738
# 2016-01-04 03:25:00+00:00        1.087208        1.086951  ...     1.08738
# 2016-01-04 03:26:00+00:00        1.087203        1.086952  ...     1.08738
# 2016-01-04 03:27:00+00:00        1.087217        1.086951  ...     1.08738
# ...                                   ...             ...  ...         ...
# 2020-12-30 23:52:00+00:00        1.230267        1.229914  ...     1.23021
# 2020-12-30 23:56:00+00:00        1.230230        1.229925  ...     1.23021
# 2020-12-30 23:57:00+00:00        1.230201        1.229932  ...     1.23021
# 2020-12-30 23:58:00+00:00        1.230194        1.229930  ...     1.23021
# 2020-12-30 23:59:00+00:00        1.230172        1.229925  ...     1.23021
#
#                            low_30min  BBANDS_UB_30min  BBANDS_LB_30min  \
# datetime
# 2016-01-04 03:23:00+00:00    1.08694         1.087235         1.086945
# 2016-01-04 03:24:00+00:00    1.08694         1.087206         1.086952
# 2016-01-04 03:25:00+00:00    1.08694         1.087208         1.086951
# 2016-01-04 03:26:00+00:00    1.08694         1.087203         1.086952
# 2016-01-04 03:27:00+00:00    1.08694         1.087217         1.086951
# ...                              ...              ...              ...
# 2020-12-30 23:52:00+00:00    1.22999         1.230267         1.229914
# 2020-12-30 23:56:00+00:00    1.22999         1.230230         1.229925
# 2020-12-30 23:57:00+00:00    1.22999         1.230201         1.229932
# 2020-12-30 23:58:00+00:00    1.22999         1.230194         1.229930
# 2020-12-30 23:59:00+00:00    1.22994         1.230172         1.229925
#
#                            SMA_SLOW_30min  SMA_FAST_30min  EMA_SLOW_30min  \
# datetime
# 2016-01-04 03:23:00+00:00        1.085524        1.086992        1.087077
# 2016-01-04 03:24:00+00:00        1.085531        1.087004        1.087073
# 2016-01-04 03:25:00+00:00        1.085539        1.087018        1.087081
# 2016-01-04 03:26:00+00:00        1.085546        1.087026        1.087083
# 2016-01-04 03:27:00+00:00        1.085553        1.087034        1.087092
# ...                                   ...             ...             ...
# 2020-12-30 23:52:00+00:00        1.229820        1.230195        1.230093
# 2020-12-30 23:56:00+00:00        1.229824        1.230195        1.230087
# 2020-12-30 23:57:00+00:00        1.229828        1.230197        1.230080
# 2020-12-30 23:58:00+00:00        1.229832        1.230195        1.230077
# 2020-12-30 23:59:00+00:00        1.229836        1.230192        1.230064
#
#                            EMA_FAST_30min  ATR_30min  RSI_30min
# datetime
# 2016-01-04 03:23:00+00:00        1.087092   0.000459  53.773095
# 2016-01-04 03:24:00+00:00        1.087079   0.000458  48.898427
# 2016-01-04 03:25:00+00:00        1.087096   0.000457  54.653511
# 2016-01-04 03:26:00+00:00        1.087096   0.000455  51.756344
# 2016-01-04 03:27:00+00:00        1.087113   0.000454  55.168743
# ...                                   ...        ...        ...
# 2020-12-30 23:52:00+00:00        1.230033   0.000244  40.742965
# 2020-12-30 23:56:00+00:00        1.230032   0.000242  40.742965
# 2020-12-30 23:57:00+00:00        1.230030   0.000240  39.826254
# 2020-12-30 23:58:00+00:00        1.230032   0.000239  42.607563
# 2020-12-30 23:59:00+00:00        1.230013   0.000241  34.116511
#
# [939941 rows x 42 columns]

# %%
train.to_csv('train_timeframes_indicators.csv', index=False)
test.to_csv('test_timeframes_indicators.csv', index=False)

# %%
train = pd.read_csv('train_timeframes2.csv')
test = pd.read_csv('test_timeframes2.csv')
